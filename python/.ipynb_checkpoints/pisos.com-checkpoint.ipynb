# %%
import requests
from bs4 import BeautifulSoup
import time
import numpy as np
import random
from itertools import cycle
from requests.exceptions import ProxyError
from lxml.html import fromstring

# %%
#proxies
proxie_file = 'proxies.txt'
try:
    with open(proxie_file) as f:
        proxies = f.readlines()
        proxy_pool = cycle(proxies)
except:
    pass

# %%
    def get_proxies2():
        url = 'https://free-proxy-list.net/'
        response = requests.get(url)
        parser = fromstring(response.text)
        proxies = set()
        for i in parser.xpath('//tbody/tr')[:10]:
            if i.xpath('.//td[7][contains(text(),"yes")]'):
                #Grabbing IP and corresponding PORT
                proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
                proxies.add(proxy)
        return proxies

# %%
   #agents
def ua_random():
        random_ua = ''
        ua_file = 'agents.txt'
        try:
            with open(ua_file) as f:
                lines = f.readlines()
            if len(lines) > 0:
                random_ua = random.choice(lines)
                random_ua = random_ua.split('\n')
        except Exception as ex:
            print('Exception in ua_random')
            print(str(ex))
        finally:
            return random_ua[0]

# %%
def quotes_parser_refs(content):
    soup1 = BeautifulSoup(content)
    
    print(soup1.prettify())

# %%
def scrape_url(url, headers):
    proxies = get_proxies2()
    proxy_pool = cycle(proxies)
    flag = False
    print(headers)
    while flag == False:
        proxy = next(proxy_pool)
        print(proxy)
        try:
            r = requests.get(url, headers = headers, proxies={"http": proxy})
            r.raise_for_status()
            #print('hola2:', BeautifulSoup(r.content).prettify())
            flag = True
            return BeautifulSoup(r.content)
            #quotes_parser_refs(r)
        except requests.exceptions.HTTPError as e_http:
            pass
            #result = "Error http:" + str(e_http)
        #except ProxyError:
            #print('Proxy Error')
            #pass
        except requests.exceptions.RequestException as e:
            pass
            #result = "Error Desconocido: " + str(e)
    if flag == False:
        # none of the proxies worked
        raise ProxyError

# %%
def parser_page(content):
    anuncios = content.find_all('div', 'information exclusivo')
    pisos = []
    for piso in anuncios:
        items = {}
        #print(piso.find('div', 'price').contents[0].strip().split(' ')[0])
        items['location1'] = piso.find('a', 'anuncioLink').string.replace('Piso en ', '')
        items['location2'] = str(piso.find('div', 'location').string).strip()
        items['price'] = piso.find('div', 'price').contents[0].strip().split(' ')[0]
        items['description'] = str(piso.find('div', 'description').string).strip()
        chars = piso.find('div', 'characteristics').find_all('div', 'item')
        #print(chars)
        for char in chars:
            #print('CONTENTS:', char.contents[0].strip())
            #print('€/m²' in char.contents[0].strip())
            #print('ICOOOONOOOOOO:',char.find('span', 'icoBed') != None)

            if '€/m²' in char.contents[0].strip():
                items['price_m2'] = char.contents[0].strip().split(' ')[0].strip()

            elif 'm²' in char.contents[0]:
                items['size'] = char.contents[0].strip().split(' ')[0]

            elif char.find('span', 'icoBed') != None:
                items['rooms'] = int(char.contents[0].strip().split(' ')[0])
                #print(items)

            elif char.find('span', 'icoBath') != None:
                items['bathrooms'] = int(char.contents[0].strip().split(' ')[0])

            elif 'planta' in char.contents[0]:
                items['floor'] = char.contents[0].strip().split(' ')[0]

            elif 'Bajo' in char.contents[0]:
                items['floor'] = 0
        
        pisos.append(items)
    return pisos

# %%
URL_general = 'https://www.pisos.com/venta/piso-madrid/%s/'
range_to_scrape = range(2, 3)
sleep = 3
headers = {'Accept-Encoding': 'gzip, deflate, br',
          'Accept-Language': 'en-US,en;q=0.9,es-ES;q=0.8,es;q=0.7',
          'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
          'Cache-Control': 'max-age=0',
          'Upgrade-Insecure-Requests': '1',
          'Refereer': 'https://www.pisos.com/venta/piso-madrid/',
          'Host': 'www.pisos.com'}
primera_pagina = None

for i in range_to_scrape:
    agent = ua_random()
    headers['user-agent'] = agent
    primera_pagina = scrape_url(URL_general % i, headers)
    time.sleep(random.randint(2, 5))
# Out:
# {'Accept-Encoding': 'gzip, deflate, br', 'Accept-Language': 'en-US,en;q=0.9,es-ES;q=0.8,es;q=0.7', 'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3', 'Cache-Control': 'max-age=0', 'Upgrade-Insecure-Requests': '1', 'Refereer': 'https://www.pisos.com/venta/piso-madrid/', 'Host': 'www.pisos.com', 'user-agent': 'BlackBerry8520/5.0.0.1036 Profile/MIDP-2.1 Configuration/CLDC-1.1 VendorID/600'}
# 176.118.51.74:36548
# hola:
# hola2: <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Pisos y apartamentos en Madrid - pisos.com
#   </title>
#   <link href="/faviconnew.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/Images/assets/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="907BFBB940FF15950271AB090B57DCCB" name="msvalidate.01"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://www.pisos.com/ca/venta/piso-madrid/2/" hreflang="ca" rel="alternate"/>
#   <link href="https://www.pisos.com/en/venta/piso-madrid/2/" hreflang="en" rel="alternate"/>
#   <meta content="noindex, follow" name="robots"/>
#   <meta content="15.748 pisos y apartamentos en venta en Madrid. Oferta de profesionales y particulares desde 499000 euros en Madrid. ¡Un piso increíble está esperándote!" name="description"/>
#   <meta content="NOODP,NOYDIR" name="robots"/>
#   <link href="https://statics.imghs.net" rel="dns-prefetch"/>
#   <link href="https://fotos.imghs.net" rel="dns-prefetch"/>
#   <link href="https://static.vocento.com" rel="dns-prefetch"/>
#   <link href="https://ajax.googleapis.com" rel="dns-prefetch"/>
#   <link href="https://static.criteo.net" rel="dns-prefetch"/>
#   <link href="https://ssl.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="https://www.googletagservices.com" rel="dns-prefetch"/>
#   <link href="https://dis.eu.criteo.com" rel="dns-prefetch"/>
#   <link href="https://assets.adobedtm.com" rel="dns-prefetch"/>
#   <link href="https://statics.imghs.net/bundles/css/desktop-common-min-9489bfca.css" rel="stylesheet"/>
#   <link href="https://statics.imghs.net/bundles/css/desktop-gridResults-min-460bb784.css" rel="stylesheet"/>
#   <script src="//code.jquery.com/jquery-2.2.4.min.js">
#   </script>
#   <script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript">
#   </script>
#   <link href="https://www.pisos.com/venta/piso-madrid/3/" rel="next"/>
#   <link href="https://www.pisos.com/venta/piso-madrid/" rel="prev"/>
#   <script>
#    var pisoscom = pisoscom || {};
#     pisoscom.resources = {"save":"Guardar","saved":"Guardado","activated_notice":"Aviso activado","search_query_saved":"Búsqueda guardada","warn_me_goes_down":"Avísame si baja","accept_legal_advice":"Debes aceptar el aviso legal","already_contacted":"Ya contactaste este anuncio","contact_again":"Contactar de nuevo","email_needed":"Necesitamos tu e-mail","valid_email":"Debes indicar un e-mail válido","already_contacted_short":"Ya has contactado","only_validate_email":"¡Sólo te falta validar tu e-mail!","send_confirmation_email":"Enviar e-mail de confirmación","to_with_spaces":" a ","update_results":"Actualizando los resultados","before":"Antes","after":"Después","watch_now":"Ver ahora"};
#   </script>
#   <script>
#    var pisoscom = pisoscom || {};
#         pisoscom.culture = 'es';
#         pisoscom.isMobileView = false;
#   </script>
#  </head>
#  <body class="Pisos" itemscope="" itemtype="http://schema.org/WebPage">
#   <input id="isViewMobile" type="hidden" value="false"/>
#   <input id="seccion" type="hidden" value="Parrilla"/>
#   <div id="floorAd">
#   </div>
#   <div class="feedBack showOn980" onclick="fby.push(['showForm', '6931']);return false;">
#    Cuéntanos
#   </div>
#   <link href="https://statics.imghs.net/bundles/css/desktop-header-min-f115de0e.css" rel="stylesheet"/>
#   <header class="">
#    <div class="header">
#     <div class="header-main">
#      <div class="header-logo">
#       <a href="https://www.pisos.com/comunidad-madrid/" target="_self">
#        <img alt="pisos.com" src="https://statics.imghs.net/Images/logo-pisos.svg" width="91"/>
#       </a>
#      </div>
#      <ul class="header-menu menu">
#       <li>
#        <ul class="menu-desktop">
#         <li class="dropdown">
#          <div class="item dropDown">
#           <div class="fkDropDown header-dropdown">
#            <div class="selector clearfix" onclick="">
#             <div class="tip">
#              Comprar
#             </div>
#            </div>
#            <div class="list">
#             <div class="joint">
#             </div>
#             <div class="box">
#              <div class="title">
#               Madrid
#              </div>
#              <div class="indent nivel3">
#               <div class="list-item">
#                <a href="https://www.pisos.com/venta/pisos-madrid/" target="_self">
#                 Casas y pisos
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/venta/casas-madrid/" target="_self">
#                 Casas y chalets
#                </a>
#               </div>
#               <div class="list-item selected">
#                <a href="https://www.pisos.com/venta/piso-madrid/" target="_self">
#                 Pisos y apartamentos
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/venta/aticos-madrid/" target="_self">
#                 Áticos
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/venta/duplexs-madrid/" target="_self">
#                 Dúplex
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/venta/estudios-madrid/" target="_self">
#                 Estudios
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/venta/lofts-madrid/" target="_self">
#                 Lofts
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="dropdown">
#          <div class="item dropDown">
#           <div class="fkDropDown header-dropdown">
#            <div class="selector clearfix" onclick="">
#             <div class="tip">
#              Alquilar
#             </div>
#            </div>
#            <div class="list">
#             <div class="joint">
#             </div>
#             <div class="box">
#              <div class="title">
#               Madrid
#              </div>
#              <div class="indent nivel3">
#               <div class="list-item">
#                <a href="https://www.pisos.com/alquiler/pisos-madrid/" target="_self">
#                 Casas y pisos
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/alquiler/casas-madrid/" target="_self">
#                 Casas y chalets
#                </a>
#               </div>
#               <div class="list-item selected">
#                <a href="https://www.pisos.com/alquiler/piso-madrid/" target="_self">
#                 Pisos y apartamentos
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/alquiler/aticos-madrid/" target="_self">
#                 Áticos
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/alquiler/duplexs-madrid/" target="_self">
#                 Dúplex
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/alquiler/estudios-madrid/" target="_self">
#                 Estudios
#                </a>
#               </div>
#               <div class="list-item">
#                <a href="https://www.pisos.com/alquiler/lofts-madrid/" target="_self">
#                 Lofts
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li>
#          <a href="https://www.pisos.com/promociones-madrid/" target="_self">
#           Obra nueva
#          </a>
#         </li>
#         <li>
#          <a href="https://www.pisocompartido.com" target="_blank">
#           Compartir
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="menu-tablet">
#        <div class="item dropDown">
#         <div class="fkDropDown header-dropdown">
#          <div class="selector clearfix" onclick="">
#           <div class="tip">
#            Comprar
#           </div>
#          </div>
#          <div class="list">
#           <div class="joint">
#           </div>
#           <div class="box">
#            <div class="list-item selected">
#             <a href="https://www.pisos.com/venta/piso-madrid/" target="_self">
#              Comprar
#             </a>
#            </div>
#            <div class="list-item">
#             <a href="https://www.pisos.com/alquiler/piso-madrid/" target="_self">
#              Alquilar
#             </a>
#            </div>
#            <div class="list-item">
#             <a href="https://www.pisos.com/promociones-madrid/" target="_self">
#              Obra nueva
#             </a>
#            </div>
#            <div class="list-item">
#             <a href="https://www.pisocompartido.com" target="_blank">
#              Compartir
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="dropdown">
#        <div class="item dropDown">
#         <div class="fkDropDown header-dropdown">
#          <div class="selector clearfix" onclick="">
#           <div class="tip">
#            Pisos al día y más
#           </div>
#          </div>
#          <div class="list">
#           <div class="joint">
#           </div>
#           <div class="box">
#            <div class="list-item">
#             <a href="//www.pisos.com/aldia/" target="_self">
#              Pisos al día
#             </a>
#            </div>
#            <div class="list-item">
#             <a href="https://www.pisos.com/Hipotecas/" target="_self">
#              Hipotecas
#             </a>
#            </div>
#            <div class="list-item">
#             <a href="https://www.pisos.com/servicios/" target="_self">
#              Servicios
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="icon-app">
#        <a class="downloads" data-click-analytics="clic-descarga,app,header" href="https://play.google.com/store/apps/details?id=com.vocento.pisos" rel="nofollow" target="_blank">
#         <img alt="Disponible Google Play" src="https://statics.imghs.net/Images/icono-android.svg"/>
#        </a>
#       </li>
#       <li class="icon-app">
#        <a class="downloads" data-click-analytics="clic-descarga,app,header" href="https://itunes.apple.com/us/app/pisos.com/id572483925?mt=8" rel="nofollow" target="_blank">
#         <img alt="Consíguela en el App Store" src="https://statics.imghs.net/Images/icono-ios.svg"/>
#        </a>
#       </li>
#      </ul>
#      <div class="header-publish-button">
#       <div class="bt bt-blue bt-uppercase" data-click-analytics="clic-home,PTA,naranja-v2" data-click-href="https://gestion.pisos.com/pta/pta_paso1.aspx" data-click-target="_self">
#        <span class="desktop">
#         Anúnciate gratis
#        </span>
#        <span class="tablet">
#         Anúnciate
#        </span>
#       </div>
#      </div>
#      <div class="multilanguageSelector" id="multilanguageSelector">
#       <div class="header-dropdown" id="selectedLanguage">
#        <div class="selected-container">
#         <div class="selected">
#          <div class="multilanguage-ballon">
#           <img src="https://statics.imghs.net/Images/icons/ballon.svg"/>
#          </div>
#          <div class="multilanguage-selected">
#           ESP
#          </div>
#         </div>
#        </div>
#        <div class="list container-languages hide" id="languagesSelectors">
#         <ul>
#          <li class="selected-item" data-click-analytics="clic-home,idioma,castellano" onclick="document.location.href='/venta/piso-madrid/2/'">
#           <a href="/venta/piso-madrid/2/">
#            Español
#           </a>
#          </li>
#          <li class="" data-click-analytics="clic-home,idioma,catalan" onclick="document.location.href='/ca/venta/piso-madrid/2/'">
#           <a href="/ca/venta/piso-madrid/2/">
#            Català
#           </a>
#          </li>
#          <li class="" data-click-analytics="clic-home,idioma,english" onclick="document.location.href='/en/venta/piso-madrid/2/'">
#           <a href="/en/venta/piso-madrid/2/">
#            English
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <script>
#       $(document).ready(function(){
#
#         $('body').on('click', function(e){
#             var clickInMultilanguageSelector = $(e.target)
#                 .parents()
#                 .is('#multilanguageSelector');
#
#             if (clickInMultilanguageSelector) {
#                 //Quitar isComingSoon cuando se habilite idioma english
#                 var isComingSoon = $(e.target).parents().is('#comingSoon') || $(e.target).is('#comingSoon');
#
#                 if (!$('#languagesSelectors').hasClass('hide') && !isComingSoon){
#                     $('#languagesSelectors').addClass('hide');
#                 }else{
#                     $('#languagesSelectors').removeClass('hide');
#                 }
#             }else{
#                 if (!$('#languagesSelectors').hasClass('hide')){
#                     $('#languagesSelectors').addClass('hide');
#                 }
#             }
#         });
#     });
#      </script>
#      <ul class="header-user-panel" data-bind-id="userPanel" id="headerUser">
#      </ul>
#     </div>
#    </div>
#   </header>
#   <div class="body">
#    <input id="contextAlert" name="contextAlert" type="hidden" value="PropertiesGrid"/>
#    <input id="Operacion" name="Operacion" type="hidden" value="1000"/>
#    <input id="hdnN" name="hdnN" type="hidden" value="0.1000.F002S021.P00000000000028.0.0X0.0.0.0X0.0.0X0X0.2.0.0X0.0X0.0"/>
#    <input id="hdnTipP" name="hdnTipP" type="hidden" value="0"/>
#    <input id="hdnTipoVista" name="hdnTipoVista" type="hidden" value="1"/>
#    <input id="hdnPage" type="hidden" value="2"/>
#    <input id="hdnBusquedaZona" type="hidden" value="Provincia"/>
#    <input id="hdnUltimaBusquedaSerialized" type="hidden" value="0.1000.F002S021.P00000000000028.0.0X0.0.0.0X0.0.0X0X0.1.0.0X0.0X0.0"/>
#    <input id="hdnAnunciosCercanosSerialized" type="hidden"/>
#    <div class="titleBox parrilla" id="dvTitulo" itemscope="" itemtype="http://schema.org/RealEstateAgent">
#     <div class="content flowed">
#      <div class="title">
#       <h1>
#        Pisos y apartamentos en
#        <b>
#         Madrid
#        </b>
#       </h1>
#      </div>
#      <div class="filters clearfix">
#       <div class="title showExcept980" data-bind-id="slideFiltros">
#        Filtros
#        <span class="icon icoDArrowThin">
#        </span>
#       </div>
#       <div class="slideBox showOn980 fLeft">
#        <div class="filtersUp filters clearfix">
#         <div class="item">
#          <div class="ms-parent w150" data-hidden-id="ddZonaProvincia" id="dd_ddZonaProvincia">
#           <button class="ms-choice" type="button">
#            <span class="black-link">
#             Madrid (5000)
#            </span>
#           </button>
#           <div class="ms-drop">
#            <div class="joint">
#            </div>
#            <div class="box">
#             <ul>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000015"/>
#                <span class="black-link">
#                 <a href="/venta/piso-a_coruna/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  A Coruña
#                 </a>
#                 (5.000)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000001"/>
#                <span class="black-link">
#                 <a href="/venta/piso-alava_araba/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Álava - Araba
#                 </a>
#                 (1.310)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000002"/>
#                <span class="black-link">
#                 <a href="/venta/piso-albacete/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Albacete
#                 </a>
#                 (2.819)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000003"/>
#                <span class="black-link">
#                 <a href="/venta/piso-alicante/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Alicante
#                 </a>
#                 (17.594)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000004"/>
#                <span class="black-link">
#                 <a href="/venta/piso-almeria/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Almería
#                 </a>
#                 (6.349)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000053"/>
#                <span class="black-link">
#                 <a href="/venta/piso-andorra_andorra/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Andorra
#                 </a>
#                 (1.281)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000033"/>
#                <span class="black-link">
#                 <a href="/venta/piso-asturias/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Asturias
#                 </a>
#                 (6.831)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000005"/>
#                <span class="black-link">
#                 <a href="/venta/piso-avila/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Ávila
#                 </a>
#                 (782)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000006"/>
#                <span class="black-link">
#                 <a href="/venta/piso-badajoz/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Badajoz
#                 </a>
#                 (3.033)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000008"/>
#                <span class="black-link">
#                 <a href="/venta/piso-barcelona/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Barcelona
#                 </a>
#                 (22.040)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000009"/>
#                <span class="black-link">
#                 <a href="/venta/piso-burgos/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Burgos
#                 </a>
#                 (2.533)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000010"/>
#                <span class="black-link">
#                 <a href="/venta/piso-caceres/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Cáceres
#                 </a>
#                 (1.000)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000011"/>
#                <span class="black-link">
#                 <a href="/venta/piso-cadiz/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Cádiz
#                 </a>
#                 (6.257)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000039"/>
#                <span class="black-link">
#                 <a href="/venta/piso-cantabria/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Cantabria
#                 </a>
#                 (7.926)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000012"/>
#                <span class="black-link">
#                 <a href="/venta/piso-castellon_castello/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Castellón - Castelló
#                 </a>
#                 (6.963)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000054"/>
#                <span class="black-link">
#                 <a href="/venta/piso-cerdanya_francesa/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Cerdanya Francesa
#                 </a>
#                 (22)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000051"/>
#                <span class="black-link">
#                 <a href="/venta/piso-ceuta/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Ceuta
#                 </a>
#                 (20)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000013"/>
#                <span class="black-link">
#                 <a href="/venta/piso-ciudad_real/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Ciudad Real
#                 </a>
#                 (1.828)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000014"/>
#                <span class="black-link">
#                 <a href="/venta/piso-cordoba/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Córdoba
#                 </a>
#                 (2.982)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000016"/>
#                <span class="black-link">
#                 <a href="/venta/piso-cuenca/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Cuenca
#                 </a>
#                 (483)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000017"/>
#                <span class="black-link">
#                 <a href="/venta/piso-girona/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Girona
#                 </a>
#                 (4.858)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000018"/>
#                <span class="black-link">
#                 <a href="/venta/piso-granada/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Granada
#                 </a>
#                 (9.200)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000019"/>
#                <span class="black-link">
#                 <a href="/venta/piso-guadalajara/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Guadalajara
#                 </a>
#                 (983)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000020"/>
#                <span class="black-link">
#                 <a href="/venta/piso-guipuzcoa_gipuzkoa/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Guipúzcoa - Gipuzkoa
#                 </a>
#                 (2.714)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000021"/>
#                <span class="black-link">
#                 <a href="/venta/piso-huelva/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Huelva
#                 </a>
#                 (2.057)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000022"/>
#                <span class="black-link">
#                 <a href="/venta/piso-huesca/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Huesca
#                 </a>
#                 (680)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000007"/>
#                <span class="black-link">
#                 <a href="/venta/piso-islas_baleares_illes_balears/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Islas Baleares - Illes Balears
#                 </a>
#                 (4.948)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000023"/>
#                <span class="black-link">
#                 <a href="/venta/piso-jaen/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Jaén
#                 </a>
#                 (1.330)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000026"/>
#                <span class="black-link">
#                 <a href="/venta/piso-la_rioja/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  La Rioja
#                 </a>
#                 (2.752)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000035"/>
#                <span class="black-link">
#                 <a href="/venta/piso-las_palmas/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Las Palmas
#                 </a>
#                 (3.273)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000024"/>
#                <span class="black-link">
#                 <a href="/venta/piso-leon/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  León
#                 </a>
#                 (2.500)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000025"/>
#                <span class="black-link">
#                 <a href="/venta/piso-lleida/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Lleida
#                 </a>
#                 (1.822)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000027"/>
#                <span class="black-link">
#                 <a href="/venta/piso-lugo/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Lugo
#                 </a>
#                 (1.099)
#                </span>
#               </label>
#              </li>
#              <li class="selected">
#               <label>
#                <input checked="checked" class="neverShow" data-prev-status="true" name="selectItem" type="checkbox" value="P00000000000028"/>
#                <span class="black-link">
#                 <a href="/venta/piso-madrid/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Madrid
#                 </a>
#                 (15.753)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000029"/>
#                <span class="black-link">
#                 <a href="/venta/piso-malaga/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Málaga
#                 </a>
#                 (16.511)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000052"/>
#                <span class="black-link">
#                 <a href="/venta/piso-melilla/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Melilla
#                 </a>
#                 (296)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000030"/>
#                <span class="black-link">
#                 <a href="/venta/piso-murcia/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Murcia
#                 </a>
#                 (9.206)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000031"/>
#                <span class="black-link">
#                 <a href="/venta/piso-navarra_nafarroa/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Navarra - Nafarroa
#                 </a>
#                 (1.877)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000032"/>
#                <span class="black-link">
#                 <a href="/venta/piso-ourense/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Ourense
#                 </a>
#                 (1.542)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000055"/>
#                <span class="black-link">
#                 <a href="/venta/piso-pais_vasco_frances_iparralde/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  País Vasco Francés - Iparralde
#                 </a>
#                 (59)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000034"/>
#                <span class="black-link">
#                 <a href="/venta/piso-palencia/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Palencia
#                 </a>
#                 (1.099)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000036"/>
#                <span class="black-link">
#                 <a href="/venta/piso-pontevedra/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Pontevedra
#                 </a>
#                 (3.948)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000037"/>
#                <span class="black-link">
#                 <a href="/venta/piso-salamanca/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Salamanca
#                 </a>
#                 (2.713)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000038"/>
#                <span class="black-link">
#                 <a href="/venta/piso-santa_cruz_de_tenerife/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Santa Cruz de Tenerife
#                 </a>
#                 (5.136)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000040"/>
#                <span class="black-link">
#                 <a href="/venta/piso-segovia/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Segovia
#                 </a>
#                 (1.063)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000041"/>
#                <span class="black-link">
#                 <a href="/venta/piso-sevilla/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Sevilla
#                 </a>
#                 (3.801)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000042"/>
#                <span class="black-link">
#                 <a href="/venta/piso-soria/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Soria
#                 </a>
#                 (112)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000043"/>
#                <span class="black-link">
#                 <a href="/venta/piso-tarragona/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Tarragona
#                 </a>
#                 (7.197)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000044"/>
#                <span class="black-link">
#                 <a href="/venta/piso-teruel/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Teruel
#                 </a>
#                 (334)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000045"/>
#                <span class="black-link">
#                 <a href="/venta/piso-toledo/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Toledo
#                 </a>
#                 (3.476)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000046"/>
#                <span class="black-link">
#                 <a href="/venta/piso-valencia/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  València
#                 </a>
#                 (19.506)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000047"/>
#                <span class="black-link">
#                 <a href="/venta/piso-valladolid/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Valladolid
#                 </a>
#                 (3.322)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000048"/>
#                <span class="black-link">
#                 <a href="/venta/piso-vizcaya_bizkaia/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Vizcaya - Bizkaia
#                 </a>
#                 (7.634)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000049"/>
#                <span class="black-link">
#                 <a href="/venta/piso-zamora/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Zamora
#                 </a>
#                 (496)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="P00000000000050"/>
#                <span class="black-link">
#                 <a href="/venta/piso-zaragoza/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Zaragoza
#                 </a>
#                 (3.372)
#                </span>
#               </label>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <input id="ddZonaProvincia" name="ddZonaProvincia" type="hidden" value=""/>
#          </div>
#         </div>
#         <div class="item">
#          <div class="ms-parent w150" data-hidden-id="ddZonaComarca" id="dd_ddZonaComarca">
#           <button class="ms-choice" type="button">
#            <span class="black-link">
#             Zonas
#            </span>
#           </button>
#           <div class="ms-drop">
#            <div class="joint">
#            </div>
#            <div class="box">
#             <ul>
#              <li class="selected">
#               <label>
#                <input checked="checked" class="neverShow" data-prev-status="true" data-select-all-text="Zonas" name="selectAll" type="checkbox" value="P00000000000028"/>
#                <span class="black-link">
#                 <a href="/venta/piso-madrid/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Todos
#                 </a>
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label class="optgroup">
#                <input class="neverShow" name="selectItem" type="checkbox" value="C00000000000193"/>
#                <span class="black-link">
#                 <a href="/venta/piso-corredor_de_henares/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Corredor de Henares
#                 </a>
#                 (1.451)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label class="optgroup">
#                <input class="neverShow" name="selectItem" type="checkbox" value="C00000000000192"/>
#                <span class="black-link">
#                 <a href="/venta/piso-madrid_capital/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Madrid Capital
#                 </a>
#                 (8.283)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label class="optgroup">
#                <input class="neverShow" name="selectItem" type="checkbox" value="C00000000000194"/>
#                <span class="black-link">
#                 <a href="/venta/piso-madrid_noroeste/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Madrid Noroeste
#                 </a>
#                 (1.587)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label class="optgroup">
#                <input class="neverShow" name="selectItem" type="checkbox" value="C00000000000195"/>
#                <span class="black-link">
#                 <a href="/venta/piso-madrid_norte/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Madrid Norte
#                 </a>
#                 (700)
#                </span>
#               </label>
#              </li>
#              <li class="child">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="Z00000000000026"/>
#                <span class="black-link">
#                 <a href="/venta/piso-area_de_alcobendas/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Área de Alcobendas
#                 </a>
#                 (528)
#                </span>
#               </label>
#              </li>
#              <li class="child">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="Z00000000000027"/>
#                <span class="black-link">
#                 <a href="/venta/piso-area_de_buitrago_del_lozoya/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Área de Buitrago del Lozoya
#                 </a>
#                 (15)
#                </span>
#               </label>
#              </li>
#              <li class="child">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="Z00000000000028"/>
#                <span class="black-link">
#                 <a href="/venta/piso-area_de_guadalix_de_la_sierra/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Área de Guadalix de la Sierra
#                 </a>
#                 (90)
#                </span>
#               </label>
#              </li>
#              <li class="child">
#               <label>
#                <input class="neverShow" name="selectItem" type="checkbox" value="Z00000000000029"/>
#                <span class="black-link">
#                 <a href="/venta/piso-area_de_manzanares_el_real/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Área de Manzanares El Real
#                 </a>
#                 (67)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label class="optgroup">
#                <input class="neverShow" name="selectItem" type="checkbox" value="C00000000000196"/>
#                <span class="black-link">
#                 <a href="/venta/piso-madrid_sur/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Madrid Sur
#                 </a>
#                 (2.205)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label class="optgroup">
#                <input class="neverShow" name="selectItem" type="checkbox" value="C00000000000197"/>
#                <span class="black-link">
#                 <a href="/venta/piso-madrid_sureste/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Madrid Sureste
#                 </a>
#                 (505)
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label class="optgroup">
#                <input class="neverShow" name="selectItem" type="checkbox" value="C00000000000198"/>
#                <span class="black-link">
#                 <a href="/venta/piso-madrid_suroeste/asc/" onclick="(function(e){e.preventDefault();})(event)">
#                  Madrid Suroeste
#                 </a>
#                 (1.022)
#                </span>
#               </label>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <input id="ddZonaComarca" name="ddZonaComarca" type="hidden" value=""/>
#          </div>
#         </div>
#        </div>
#        <div class="filtersDown filters clearfix">
#         <div class="item">
#          <div class="ms-parent w150" data-hidden-id="ddTipologias176" data-multiple="true" id="dd_ddTipologias176">
#           <button class="ms-choice" type="button">
#            <span class="black-link">
#             Pisos y apartamentos (15.748) (0)
#            </span>
#           </button>
#           <div class="ms-drop">
#            <div class="joint">
#            </div>
#            <div class="box multiple">
#             <ul>
#              <li class="">
#               <label>
#                <div class="fkCheckbox noEvents">
#                 <input class="neverShow" data-select-all-text="Tipo de inmueble" name="selectAll" type="checkbox" value="F002"/>
#                 <label class="box" onclick="">
#                  <label class="icoTick" onclick="">
#                  </label>
#                 </label>
#                </div>
#                <span class="black-link">
#                 <label>
#                  Todos
#                 </label>
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <div class="fkCheckbox noEvents">
#                 <input class="neverShow" name="selectItem" type="checkbox" value="F002S022"/>
#                 <label class="box" onclick="">
#                  <label class="icoTick" onclick="">
#                  </label>
#                 </label>
#                </div>
#                <span class="black-link">
#                 <a href="/venta/casas-madrid/" onclick="(function(e){e.preventDefault();})(event)">
#                  Casas y chalets (7.758)
#                 </a>
#                </span>
#               </label>
#              </li>
#              <li class="">
#               <label>
#                <div class="fkCheckbox noEvents">
#                 <input checked="checked" class="neverShow" data-prev-status="true" name="selectItem" type="checkbox" value="F002S021"/>
#                 <label class="box" onclick="">
# ...
#         5
#        </a>
#        <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-6-v2" href="/venta/piso-madrid/6/">
#         6
#        </a>
#        <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-7-v2" href="/venta/piso-madrid/7/">
#         7
#        </a>
#        <span class="item ellipsis">
#         ...
#        </span>
#        <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-525-v2" href="/venta/piso-madrid/525/">
#         525
#        </a>
#        <a class="button gray w162h32 right" data-click-analytics="clic-parrilla,paginador,siguiente-bottom-v2-blankOnclic" href="/venta/piso-madrid/3/" id="lnkPagSig" rel="next">
#         <span class="showOn980">
#          Siguiente
#         </span>
#        </a>
#       </div>
#       <h2 class="subTitle">
#        Venta de pisos y apartamentos en Madrid: 15.748 disponibles
#       </h2>
#      </div>
#      <div id="contactarEspecialista">
#      </div>
#      <div class="btnUp button darkGray w50h50">
#       <span class="icon icoUArrowThin" data-click-analytics="clic-parrilla,desplegable-H1,v2">
#       </span>
#      </div>
#     </div>
#    </div>
#    <div class="content">
#     <div class="adSenseDownPartial" data-querystring="0.1000.F002S021.P00000000000028.0.0X0.0.0.0X0.0.0X0X0.2.0.0X0.0X0.0" id="adSenseDownPartial">
#      <div class="lazyLoad" data-ctrl="adSenseDownPartial">
#       <div class="box">
#        <span class="icon icoLoad">
#        </span>
#        Cargando...
#       </div>
#      </div>
#     </div>
#     <div class="neverShow" id="divGuardarBusquedaInferior">
#      <div class="modals">
#       <div class="integratedBlock">
#        <form action="/Alerta/guardarAlertaIncrustado?cu=es" data-ajax="true" data-ajax-begin="$.Forms.desactivaBoton('.guardarAlerta input[type=&quot;submit&quot;]');" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-success="$.FormsAlerta.getAlertaResponse($.FormsAlerta.TIPO_FORM_INCRUSTADO);" data-ajax-update="#guardarAlerta" id="form0" method="post">
#         <div class="guardarAlerta clearfix" id="guardarAlerta">
#          <div class="icono">
#           <span class="icoBell">
#           </span>
#          </div>
#          <h3 class="aviso">
#           Te avisamos de las últimas novedades en pisos y apartamentos en Madrid
#          </h3>
#          <div class="alerta clearfix">
#           <input class="button blue w140h32" type="submit" value="Guardar búsqueda"/>
#           <div class="fkInput w250">
#            <input data-default-value="Escribe tu e-mail" data-val="true" data-val-regex="Introduce un e-mail correcto." data-val-regex-pattern="^[\w!#$%&amp;'*+\-/=?\^_`{|}~]+(\.[\w!#$%&amp;'*+\-/=?\^_`{|}~]+)*(?!.*@.*@)@[^-.]((([\-\w]+\.)+[a-zA-Z]{2,})|(([0-9]{1,3}\.){3}[0-9]{1,3}))$" data-val-required="Introduce un e-mail correcto." id="email" name="email" placeholder="" type="text" value=""/>
#           </div>
#           <span class="field-validation-valid" data-valmsg-for="email" data-valmsg-replace="true">
#           </span>
#          </div>
#          <div class="contact-line check">
#           <div class="error">
#            <span class="field-validation-valid inputfield-error" data-valmsg-for="AvisoLegal" data-valmsg-replace="true">
#            </span>
#           </div>
#           <div class="chkBox">
#            <div class="fkCheckbox">
#             <input data-val="true" data-val-required="The AvisoLegal field is required." id="AvisoLegalAA3" name="AvisoLegal" type="checkbox" value="true"/>
#             <input name="AvisoLegal" type="hidden" value="false"/>
#             <label class="box" for="AvisoLegalAA3" onclick="">
#              <label class="icoTick" for="AvisoLegalAA3" onclick="">
#              </label>
#             </label>
#            </div>
#           </div>
#           <label class="checkbox-text" for="AvisoLegalAA3">
#            He leído el
#            <a href="//www.pisos.com/avisolegal" target="_blank">
#             aviso legal y la política de privacidad
#            </a>
#           </label>
#          </div>
#          <input id="AnuncioId" name="AnuncioId" type="hidden" value=""/>
#          <input data-val="true" data-val-required="The IsPromotion field is required." id="IsPromotion" name="IsPromotion" type="hidden" value="False"/>
#          <input data-val="true" data-val-required="The OrigenPortalAnuncio field is required." id="OrigenPortalAnuncio" name="OrigenPortalAnuncio" type="hidden" value="Pisos"/>
#          <input id="hdnQueryString" name="queryString" type="hidden" value="0.1000.F002S021.P00000000000028.0.0X0.0.0.0X0.0.0X0X0.2.0.0X0.0X0.0"/>
#          <input data-val="true" data-val-required="The Origen field is required." id="hdnOrigenAlerta" name="Origen" type="hidden" value="AlertaParrilla_BarraInferior"/>
#          <input id="hdnTipoAlerta" name="hdnTipoAlerta" type="hidden" value="0"/>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="content">
#     <div class="linksSeo clearfix">
#      <h3 class="titulo">
#       Te recomendamos...
#      </h3>
#      <div class="tipo">
#       <span class="subtitulo">
#        Top municipios
#       </span>
#       <div class="columna">
#        <a class="item" href="/venta/piso-madrid_capital_zona_urbana/" title="Casas y pisos en venta en Madrid Capital">
#         Madrid Capital
#        </a>
#        <a class="item" href="/venta/piso-torrejon_de_ardoz/" title="Casas y pisos en venta en Torrejón de Ardoz">
#         Torrejón de Ardoz
#        </a>
#        <a class="item" href="/venta/piso-mostoles/" title="Casas y pisos en venta en Móstoles">
#         Móstoles
#        </a>
#        <a class="item" href="/venta/piso-alcala_de_henares/" title="Casas y pisos en venta en Alcalá de Henares">
#         Alcalá de Henares
#        </a>
#        <a class="item" href="/venta/piso-fuenlabrada/" title="Casas y pisos en venta en Fuenlabrada">
#         Fuenlabrada
#        </a>
#       </div>
#      </div>
#      <div class="cerca">
#       <span class="subtitulo">
#        Cerca de Madrid
#       </span>
#       <div class="columna col0">
#        <a class="item" href="/venta/piso-madrid_capital_zona_urbana/" title="Venta De Pisos y apartamentos en Madrid Capital">
#         Madrid Capital
#        </a>
#        <a class="item" href="/venta/piso-alcobendas/" title="Venta De Pisos y apartamentos en Alcobendas">
#         Alcobendas
#        </a>
#        <a class="item" href="/venta/piso-pozuelo_de_alarcon/" title="Venta De Pisos y apartamentos en Pozuelo de Alarcón">
#         Pozuelo de Alarcón
#        </a>
#        <a class="item" href="/venta/piso-tres_cantos/" title="Venta De Pisos y apartamentos en Tres Cantos">
#         Tres Cantos
#        </a>
#        <a class="item" href="/venta/piso-san_sebastian_de_los_reyes/" title="Venta De Pisos y apartamentos en San Sebastián de los Reyes">
#         San Sebastián de los Reyes
#        </a>
#       </div>
#       <div class="columna col1">
#        <a class="item" href="/venta/piso-las_rozas_de_madrid/" title="Venta De Pisos y apartamentos en Las Rozas de Madrid">
#         Las Rozas de Madrid
#        </a>
#        <a class="item" href="/venta/piso-majadahonda/" title="Venta De Pisos y apartamentos en Majadahonda">
#         Majadahonda
#        </a>
#        <a class="item" href="/venta/piso-coslada/" title="Venta De Pisos y apartamentos en Coslada">
#         Coslada
#        </a>
#        <a class="item" href="/venta/piso-paracuellos_de_jarama/" title="Venta De Pisos y apartamentos en Paracuellos de Jarama">
#         Paracuellos de Jarama
#        </a>
#        <a class="item" href="/venta/piso-boadilla_del_monte/" title="Venta De Pisos y apartamentos en Boadilla del Monte">
#         Boadilla del Monte
#        </a>
#       </div>
#       <div class="columna col2">
#        <a class="item" href="/venta/piso-alcorcon/" title="Venta De Pisos y apartamentos en Alcorcón">
#         Alcorcón
#        </a>
#        <a class="item" href="/venta/piso-leganes/" title="Venta De Pisos y apartamentos en Leganés">
#         Leganés
#        </a>
#        <a class="item" href="/venta/piso-colmenar_viejo/" title="Venta De Pisos y apartamentos en Colmenar Viejo">
#         Colmenar Viejo
#        </a>
#        <a class="item" href="/venta/piso-cobena/" title="Venta De Pisos y apartamentos en Cobeña">
#         Cobeña
#        </a>
#        <a class="item" href="/venta/piso-torrelodones/" title="Venta De Pisos y apartamentos en Torrelodones">
#         Torrelodones
#        </a>
#       </div>
#       <div class="columna col3">
#       </div>
#      </div>
#     </div>
#    </div>
#    <input id="hdnTipoDisp" name="hdnTipoDisp" type="hidden" value="Mobile"/>
#    <script type="text/javascript">
#     if ("headScripts" in jQuery) { $.headScripts.parrillaOnError(); }
#    </script>
#   </div>
#   <link href="https://statics.imghs.net/bundles/css/desktop-footer-min-cef6c40f.css" rel="stylesheet"/>
#   <footer>
#    <div class="footer">
#     <div class="footer-content">
#      <div class="footer-breadcrumb" itemprop="breadcrumb">
#       <div class="item">
#        <a href="/" target="_self">
#         Inicio
#        </a>
#       </div>
#       <div class="separator">
#        &gt;
#       </div>
#       <div class="item">
#        Pisos y apartamentos en venta en Madrid
#       </div>
#       <div class="clear">
#       </div>
#      </div>
#      <div class="footer-row">
#       <div class="footer-sociallinks">
#        <img alt="pisos.com" class="footer-logo" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/logo-pisos-footer.svg" src="/Images/assets/blank1x1.png" width="75"/>
#        <a href="https://twitter.com/pisoscom" rel="nofollow" target="_blank">
#         <img alt="Twitter" class="icon-social" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/footer-twitter.svg" src="/Images/assets/blank1x1.png"/>
#        </a>
#        <a href="https://www.facebook.com/pisoscom" rel="nofollow" target="_blank">
#         <img alt="Facebook" class="icon-social" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/footer-facebook.svg" src="/Images/assets/blank1x1.png"/>
#        </a>
#       </div>
#       <div class="footer-stores">
#        <a class="mobile-landing" href="https://www.pisos.com/movil/" rel="nofollow" target="_blank">
#         <span>
#          También en tu móvil
#         </span>
#         <img alt="icono-moviles" src="https://statics.imghs.net/Images/icono-moviles.svg"/>
#        </a>
#        <a data-click-analytics="clic-descarga,app,footer" href="https://play.google.com/store/apps/details?id=com.vocento.pisos" rel="nofollow" target="_blank">
#         <img alt="icono-footer-android" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/icono-footer-android.svg" src="/Images/assets/blank1x1.png"/>
#         <span>
#          Para Android
#         </span>
#        </a>
#        <a data-click-analytics="clic-descarga,app,footer" href="https://itunes.apple.com/us/app/pisos.com/id572483925?mt=8" rel="nofollow" target="_blank">
#         <img alt="icono-footer-ios" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/icono-footer-ios.svg" src="/Images/assets/blank1x1.png"/>
#         <span>
#          Para IOS
#         </span>
#        </a>
#       </div>
#      </div>
#      <div class="footer-links">
#       <div class="footer-column">
#        <div class="title">
#         Corporativo
#        </div>
#        <div class="item">
#         <a href="https://www.pisos.com/sobrepisos/" rel="nofollow" target="">
#          Sobre pisos.com
#         </a>
#        </div>
#        <div class="item">
#         <a href="https://www.pisos.com/sobrepisos/contactanos/" rel="nofollow" target="">
#          Contactar
#         </a>
#        </div>
#       </div>
#       <div class="footer-column">
#        <div class="title">
#        </div>
#        <div class="item">
#         <a href="https://www.pisos.com/saladeprensa/" rel="nofollow" target="">
#          Sala de prensa
#         </a>
#        </div>
#        <div class="item">
#         <a href="https://www.pisos.com/mapaweb/">
#          Mapa web
#         </a>
#        </div>
#       </div>
#       <div class="footer-column">
#        <div class="title">
#         Secciones
#        </div>
#        <div class="item">
#         <a href="https://gestion.pisos.com/pta/pta_paso1.aspx" rel="nofollow">
#          Publica tu anuncio
#         </a>
#        </div>
#        <div class="item">
#         <a href="https://www.pisos.com/hipotecas/">
#          Hipotecas
#         </a>
#        </div>
#       </div>
#       <div class="footer-column">
#        <div class="title">
#        </div>
#        <div class="item">
#         <a href="https://www.pisos.com/servicios/" rel="nofollow" target="">
#          Servicios
#         </a>
#        </div>
#        <div class="item">
#         <a href="//www.pisos.com/aldia/">
#          Pisos al día
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="clear">
#      </div>
#      <div class="footer-copyright">
#       <div class="copyright">
#        Copyright © 1998-2019 Portal inmobiliario pisos.com es un producto de
#        <a href="http://www.habitatsoft.com/" target="_blank">
#         HabitatSoft
#        </a>
#        |
#        <a data-bind-id="avisoLegal">
#         Aviso legal y política de privacidad
#        </a>
#       </div>
#       <div class="vocento">
#        <a href="https://www.vocento.com/" target="_blank">
#         <img alt="Vocento" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/logo-vocento.svg" src="/Images/assets/blank1x1.png"/>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <span data-bot="false" data-ip="81.0.23.142" data-new-session="false" data-page-name="resultados-navegacion/viviendas-venta/madrid/provincia/madrid/2" data-session-id="" data-url="http://www.pisos.com/venta/piso-madrid/2/" data-url-ref="" data-var-ads="Venta/parrillas#prv=28#ti=F002S021#tu=2#mob=0" id="gaVars">
#   </span>
#   <span data-var="1,tipo_operacion,venta,3;2,tipo_inmueble,piso,3;3,pr_madrid,,3;5,usuario,no-loggado,2" id="gaCusVar">
#   </span>
#   <span data-base-gestion-url="https://gestion.pisos.com/" data-base-url="https://www.pisos.com/" id="AdditionalVars">
#   </span>
#   <span data-category="Venta" data-category-id="" data-exclude-rtbhouse="false" data-id="" data-id-list="94198207921.997755,9006950068.109700,93420502200.101800,94183796118.109300,88396535652.104400,945856909523055.109700,93389918534.995758,94181579146.101800,94175007538.149200,93338616709.109300,93426476345.100500,92576193051.100500,93394502626.995758,90056004224.100500,93334078717.109300,94197480219.100500,92526632830.997869,94231056919.100500,92534256010.998331,89232638534.510261,90853895315.992271,92513508417.109300,94240631085.515111,92573887005.100500,92540793095.993744,9113098299.109700,83395212035.390800,92519655450.108900,94174864462.100500,85857913219.104400" data-type="listing" data-var-hash="mHKAyYGLw7B5JdS8yAaa" id="RTBHouse">
#   </span>
#   <input id="hdnsrv" type="hidden" value="SHADOW"/>
#   <script data-cmp="true" src="//static.vocento.com/voonto2/latest/voonto.js">
#   </script>
#   <script data-legacy-comscore-mmx="7715761" data-property-id="9cb981201c2474d6a4604b74a0c58d334d976adc" src="//static.vocento.com/tag-manager/latest/vtm.js">
#   </script>
#   <script>
#    if (typeof (TagManager) !== "undefined") {
#         TagManager.ready.then(function () { TagManager.set({ sitioRegistro: 'pisos' }).track(); });
#     }
#   </script>
#   <noscript>
#    <img border="0" height="1" src="//vocento.d3.omtrdc.net/b/ss/vocpisos,voces/1/G.4--S/886540940?pageName=&amp;g=" width="1"/>
#   </noscript>
#   <link href="https://statics.imghs.net/bundles/css/common-mediaqueries-min-1a7ef7f1.css" rel="stylesheet"/>
#   <script src="https://statics.imghs.net/bundles/js/common-jquery-min-aa814b7a.js">
#   </script>
#   <script src="https://statics.imghs.net/bundles/js/common-google-min-f980b9fb.js">
#   </script>
#   <script src="https://statics.imghs.net/bundles/js/common-shared-min-7caaf192.js">
#   </script>
#   <script src="https://statics.imghs.net/bundles/js/common-business-min-bc58aff4.js">
#   </script>
#   <script src="https://statics.imghs.net/bundles/js/desktop-grid-min-5e9ae7d0.js">
#   </script>
#   <script type="text/javascript">
#    var _emailSubscrito = '';
#         var _idUsuario = 0;
#   </script>
#  </body>
# </html>

# %%
'''
with requests.session() as r:
    page = None

    for _ in range(len(d)):
        d.rotate(-1)
        try:
            page = r.get(line.rstrip(), proxies=d[0])
        except ProxyError:
            # ignore proxy exception, move to next proxy
            pass
        else:
            # success, break loop
            break

    if page is None:
        # none of the proxies worked
        raise ProxyError
'''
# Out:
# '\nwith requests.session() as r:\n    page = None\n\n    for _ in range(len(d)):\n        d.rotate(-1)\n        try:\n            page = r.get(line.rstrip(), proxies=d[0])\n        except ProxyError:\n            # ignore proxy exception, move to next proxy\n            pass\n        else:\n            # success, break loop\n            break\n\n    if page is None:\n        # none of the proxies worked\n        raise ProxyError\n'

# %%
primera_pagina
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Pisos y apartamentos en Madrid - pisos.com</title>
# <link href="/faviconnew.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/Images/assets/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="907BFBB940FF15950271AB090B57DCCB" name="msvalidate.01"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://www.pisos.com/ca/venta/piso-madrid/2/" hreflang="ca" rel="alternate"/><link href="https://www.pisos.com/en/venta/piso-madrid/2/" hreflang="en" rel="alternate"/>
# <meta content="noindex, follow" name="robots"/> <meta content="15.748 pisos y apartamentos en venta en Madrid. Oferta de profesionales y particulares desde 499000 euros en Madrid. ¡Un piso increíble está esperándote!" name="description"/><meta content="NOODP,NOYDIR" name="robots"/>
# <link href="https://statics.imghs.net" rel="dns-prefetch"/>
# <link href="https://fotos.imghs.net" rel="dns-prefetch"/>
# <link href="https://static.vocento.com" rel="dns-prefetch"/>
# <link href="https://ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="https://static.criteo.net" rel="dns-prefetch"/>
# <link href="https://ssl.google-analytics.com" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="https://www.googletagservices.com" rel="dns-prefetch"/>
# <link href="https://dis.eu.criteo.com" rel="dns-prefetch"/>
# <link href="https://assets.adobedtm.com" rel="dns-prefetch"/>
# <link href="https://statics.imghs.net/bundles/css/desktop-common-min-9489bfca.css" rel="stylesheet"/>
# <link href="https://statics.imghs.net/bundles/css/desktop-gridResults-min-460bb784.css" rel="stylesheet"/>
# <script src="//code.jquery.com/jquery-2.2.4.min.js"></script>
# <script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>
# <link href="https://www.pisos.com/venta/piso-madrid/3/" rel="next"/>
# <link href="https://www.pisos.com/venta/piso-madrid/" rel="prev"/>
# <script>
#     var pisoscom = pisoscom || {};
#     pisoscom.resources = {"save":"Guardar","saved":"Guardado","activated_notice":"Aviso activado","search_query_saved":"Búsqueda guardada","warn_me_goes_down":"Avísame si baja","accept_legal_advice":"Debes aceptar el aviso legal","already_contacted":"Ya contactaste este anuncio","contact_again":"Contactar de nuevo","email_needed":"Necesitamos tu e-mail","valid_email":"Debes indicar un e-mail válido","already_contacted_short":"Ya has contactado","only_validate_email":"¡Sólo te falta validar tu e-mail!","send_confirmation_email":"Enviar e-mail de confirmación","to_with_spaces":" a ","update_results":"Actualizando los resultados","before":"Antes","after":"Después","watch_now":"Ver ahora"};
# </script>
# <script>
#         var pisoscom = pisoscom || {};
#         pisoscom.culture = 'es';
#         pisoscom.isMobileView = false;
#     </script>
# </head>
# <body class="Pisos" itemscope="" itemtype="http://schema.org/WebPage">
# <input id="isViewMobile" type="hidden" value="false"/>
# <input id="seccion" type="hidden" value="Parrilla"/>
# <div id="floorAd"></div>
# <div class="feedBack showOn980" onclick="fby.push(['showForm', '6931']);return false;">
#             Cuéntanos
#         </div>
# <link href="https://statics.imghs.net/bundles/css/desktop-header-min-f115de0e.css" rel="stylesheet"/>
# <header class="">
# <div class="header">
# <div class="header-main">
# <div class="header-logo">
# <a href="https://www.pisos.com/comunidad-madrid/" target="_self"><img alt="pisos.com" src="https://statics.imghs.net/Images/logo-pisos.svg" width="91"/></a>
# </div>
# <ul class="header-menu menu">
# <li>
# <ul class="menu-desktop">
# <li class="dropdown">
# <div class="item dropDown">
# <div class="fkDropDown header-dropdown">
# <div class="selector clearfix" onclick="">
# <div class="tip">Comprar</div>
# </div>
# <div class="list">
# <div class="joint"></div>
# <div class="box">
# <div class="title">Madrid</div>
# <div class="indent nivel3">
# <div class="list-item"><a href="https://www.pisos.com/venta/pisos-madrid/" target="_self">Casas y pisos</a></div>
# <div class="list-item"><a href="https://www.pisos.com/venta/casas-madrid/" target="_self">Casas y chalets</a></div>
# <div class="list-item selected"><a href="https://www.pisos.com/venta/piso-madrid/" target="_self">Pisos y apartamentos</a></div>
# <div class="list-item"><a href="https://www.pisos.com/venta/aticos-madrid/" target="_self">Áticos</a></div>
# <div class="list-item"><a href="https://www.pisos.com/venta/duplexs-madrid/" target="_self">Dúplex</a></div>
# <div class="list-item"><a href="https://www.pisos.com/venta/estudios-madrid/" target="_self">Estudios</a></div>
# <div class="list-item"><a href="https://www.pisos.com/venta/lofts-madrid/" target="_self">Lofts</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="dropdown">
# <div class="item dropDown">
# <div class="fkDropDown header-dropdown">
# <div class="selector clearfix" onclick="">
# <div class="tip">Alquilar</div>
# </div>
# <div class="list">
# <div class="joint"></div>
# <div class="box">
# <div class="title">Madrid</div>
# <div class="indent nivel3">
# <div class="list-item"><a href="https://www.pisos.com/alquiler/pisos-madrid/" target="_self">Casas y pisos</a></div>
# <div class="list-item"><a href="https://www.pisos.com/alquiler/casas-madrid/" target="_self">Casas y chalets</a></div>
# <div class="list-item selected"><a href="https://www.pisos.com/alquiler/piso-madrid/" target="_self">Pisos y apartamentos</a></div>
# <div class="list-item"><a href="https://www.pisos.com/alquiler/aticos-madrid/" target="_self">Áticos</a></div>
# <div class="list-item"><a href="https://www.pisos.com/alquiler/duplexs-madrid/" target="_self">Dúplex</a></div>
# <div class="list-item"><a href="https://www.pisos.com/alquiler/estudios-madrid/" target="_self">Estudios</a></div>
# <div class="list-item"><a href="https://www.pisos.com/alquiler/lofts-madrid/" target="_self">Lofts</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li><a href="https://www.pisos.com/promociones-madrid/" target="_self">Obra nueva</a></li>
# <li><a href="https://www.pisocompartido.com" target="_blank">Compartir</a></li>
# </ul>
# </li>
# <li class="menu-tablet">
# <div class="item dropDown">
# <div class="fkDropDown header-dropdown">
# <div class="selector clearfix" onclick="">
# <div class="tip">Comprar</div>
# </div>
# <div class="list">
# <div class="joint"></div>
# <div class="box">
# <div class="list-item selected"><a href="https://www.pisos.com/venta/piso-madrid/" target="_self">Comprar</a></div>
# <div class="list-item"><a href="https://www.pisos.com/alquiler/piso-madrid/" target="_self">Alquilar</a></div>
# <div class="list-item"><a href="https://www.pisos.com/promociones-madrid/" target="_self">Obra nueva</a></div>
# <div class="list-item"><a href="https://www.pisocompartido.com" target="_blank">Compartir</a></div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="dropdown">
# <div class="item dropDown">
# <div class="fkDropDown header-dropdown">
# <div class="selector clearfix" onclick="">
# <div class="tip">Pisos al día y más</div>
# </div>
# <div class="list">
# <div class="joint"></div>
# <div class="box">
# <div class="list-item"><a href="//www.pisos.com/aldia/" target="_self">Pisos al día</a></div>
# <div class="list-item"><a href="https://www.pisos.com/Hipotecas/" target="_self">Hipotecas</a></div>
# <div class="list-item"><a href="https://www.pisos.com/servicios/" target="_self">Servicios</a></div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="icon-app">
# <a class="downloads" data-click-analytics="clic-descarga,app,header" href="https://play.google.com/store/apps/details?id=com.vocento.pisos" rel="nofollow" target="_blank">
# <img alt="Disponible Google Play" src="https://statics.imghs.net/Images/icono-android.svg"/>
# </a>
# </li>
# <li class="icon-app">
# <a class="downloads" data-click-analytics="clic-descarga,app,header" href="https://itunes.apple.com/us/app/pisos.com/id572483925?mt=8" rel="nofollow" target="_blank">
# <img alt="Consíguela en el App Store" src="https://statics.imghs.net/Images/icono-ios.svg"/>
# </a>
# </li>
# </ul>
# <div class="header-publish-button">
# <div class="bt bt-blue bt-uppercase" data-click-analytics="clic-home,PTA,naranja-v2" data-click-href="https://gestion.pisos.com/pta/pta_paso1.aspx" data-click-target="_self">
# <span class="desktop">Anúnciate gratis</span>
# <span class="tablet">Anúnciate</span>
# </div>
# </div>
# <div class="multilanguageSelector" id="multilanguageSelector">
# <div class="header-dropdown" id="selectedLanguage">
# <div class="selected-container">
# <div class="selected">
# <div class="multilanguage-ballon"><img src="https://statics.imghs.net/Images/icons/ballon.svg"/></div>
# <div class="multilanguage-selected">ESP</div>
# </div>
# </div>
# <div class="list container-languages hide" id="languagesSelectors">
# <ul>
# <li class="selected-item" data-click-analytics="clic-home,idioma,castellano" onclick="document.location.href='/venta/piso-madrid/2/'">
# <a href="/venta/piso-madrid/2/">Español</a>
# </li>
# <li class="" data-click-analytics="clic-home,idioma,catalan" onclick="document.location.href='/ca/venta/piso-madrid/2/'">
# <a href="/ca/venta/piso-madrid/2/">Català</a>
# </li>
# <li class="" data-click-analytics="clic-home,idioma,english" onclick="document.location.href='/en/venta/piso-madrid/2/'">
# <a href="/en/venta/piso-madrid/2/">English</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script>
#     $(document).ready(function(){
#
#         $('body').on('click', function(e){
#             var clickInMultilanguageSelector = $(e.target)
#                 .parents()
#                 .is('#multilanguageSelector');
#
#             if (clickInMultilanguageSelector) {
#                 //Quitar isComingSoon cuando se habilite idioma english
#                 var isComingSoon = $(e.target).parents().is('#comingSoon') || $(e.target).is('#comingSoon');
#
#                 if (!$('#languagesSelectors').hasClass('hide') && !isComingSoon){
#                     $('#languagesSelectors').addClass('hide');
#                 }else{
#                     $('#languagesSelectors').removeClass('hide');
#                 }
#             }else{
#                 if (!$('#languagesSelectors').hasClass('hide')){
#                     $('#languagesSelectors').addClass('hide');
#                 }
#             }
#         });
#     });
# </script>
# <ul class="header-user-panel" data-bind-id="userPanel" id="headerUser"></ul>
# </div>
# </div>
# </header>
# <div class="body">
# <input id="contextAlert" name="contextAlert" type="hidden" value="PropertiesGrid"/>
# <input id="Operacion" name="Operacion" type="hidden" value="1000"/>
# <input id="hdnN" name="hdnN" type="hidden" value="0.1000.F002S021.P00000000000028.0.0X0.0.0.0X0.0.0X0X0.2.0.0X0.0X0.0"/>
# <input id="hdnTipP" name="hdnTipP" type="hidden" value="0"/>
# <input id="hdnTipoVista" name="hdnTipoVista" type="hidden" value="1"/>
# <input id="hdnPage" type="hidden" value="2"/>
# <input id="hdnBusquedaZona" type="hidden" value="Provincia"/>
# <input id="hdnUltimaBusquedaSerialized" type="hidden" value="0.1000.F002S021.P00000000000028.0.0X0.0.0.0X0.0.0X0X0.1.0.0X0.0X0.0"/>
# <input id="hdnAnunciosCercanosSerialized" type="hidden"/>
# <div class="titleBox parrilla" id="dvTitulo" itemscope="" itemtype="http://schema.org/RealEstateAgent">
# <div class="content flowed">
# <div class="title">
# <h1>Pisos y apartamentos en <b>Madrid</b></h1>
# </div>
# <div class="filters clearfix">
# <div class="title showExcept980" data-bind-id="slideFiltros">
#             Filtros <span class="icon icoDArrowThin"></span>
# </div>
# <div class="slideBox showOn980 fLeft">
# <div class="filtersUp filters clearfix">
# <div class="item">
# <div class="ms-parent w150" data-hidden-id="ddZonaProvincia" id="dd_ddZonaProvincia"><button class="ms-choice" type="button"><span class="black-link">Madrid (5000)</span></button><div class="ms-drop"><div class="joint"></div><div class="box"><ul><li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000015"/><span class="black-link"><a href="/venta/piso-a_coruna/asc/" onclick="(function(e){e.preventDefault();})(event)">A Coruña</a> (5.000)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000001"/><span class="black-link"><a href="/venta/piso-alava_araba/asc/" onclick="(function(e){e.preventDefault();})(event)">Álava - Araba</a> (1.310)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000002"/><span class="black-link"><a href="/venta/piso-albacete/asc/" onclick="(function(e){e.preventDefault();})(event)">Albacete</a> (2.819)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000003"/><span class="black-link"><a href="/venta/piso-alicante/asc/" onclick="(function(e){e.preventDefault();})(event)">Alicante</a> (17.594)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000004"/><span class="black-link"><a href="/venta/piso-almeria/asc/" onclick="(function(e){e.preventDefault();})(event)">Almería</a> (6.349)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000053"/><span class="black-link"><a href="/venta/piso-andorra_andorra/asc/" onclick="(function(e){e.preventDefault();})(event)">Andorra</a> (1.281)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000033"/><span class="black-link"><a href="/venta/piso-asturias/asc/" onclick="(function(e){e.preventDefault();})(event)">Asturias</a> (6.831)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000005"/><span class="black-link"><a href="/venta/piso-avila/asc/" onclick="(function(e){e.preventDefault();})(event)">Ávila</a> (782)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000006"/><span class="black-link"><a href="/venta/piso-badajoz/asc/" onclick="(function(e){e.preventDefault();})(event)">Badajoz</a> (3.033)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000008"/><span class="black-link"><a href="/venta/piso-barcelona/asc/" onclick="(function(e){e.preventDefault();})(event)">Barcelona</a> (22.040)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000009"/><span class="black-link"><a href="/venta/piso-burgos/asc/" onclick="(function(e){e.preventDefault();})(event)">Burgos</a> (2.533)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000010"/><span class="black-link"><a href="/venta/piso-caceres/asc/" onclick="(function(e){e.preventDefault();})(event)">Cáceres</a> (1.000)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000011"/><span class="black-link"><a href="/venta/piso-cadiz/asc/" onclick="(function(e){e.preventDefault();})(event)">Cádiz</a> (6.257)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000039"/><span class="black-link"><a href="/venta/piso-cantabria/asc/" onclick="(function(e){e.preventDefault();})(event)">Cantabria</a> (7.926)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000012"/><span class="black-link"><a href="/venta/piso-castellon_castello/asc/" onclick="(function(e){e.preventDefault();})(event)">Castellón - Castelló</a> (6.963)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000054"/><span class="black-link"><a href="/venta/piso-cerdanya_francesa/asc/" onclick="(function(e){e.preventDefault();})(event)">Cerdanya Francesa</a> (22)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000051"/><span class="black-link"><a href="/venta/piso-ceuta/asc/" onclick="(function(e){e.preventDefault();})(event)">Ceuta</a> (20)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000013"/><span class="black-link"><a href="/venta/piso-ciudad_real/asc/" onclick="(function(e){e.preventDefault();})(event)">Ciudad Real</a> (1.828)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000014"/><span class="black-link"><a href="/venta/piso-cordoba/asc/" onclick="(function(e){e.preventDefault();})(event)">Córdoba</a> (2.982)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000016"/><span class="black-link"><a href="/venta/piso-cuenca/asc/" onclick="(function(e){e.preventDefault();})(event)">Cuenca</a> (483)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000017"/><span class="black-link"><a href="/venta/piso-girona/asc/" onclick="(function(e){e.preventDefault();})(event)">Girona</a> (4.858)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000018"/><span class="black-link"><a href="/venta/piso-granada/asc/" onclick="(function(e){e.preventDefault();})(event)">Granada</a> (9.200)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000019"/><span class="black-link"><a href="/venta/piso-guadalajara/asc/" onclick="(function(e){e.preventDefault();})(event)">Guadalajara</a> (983)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000020"/><span class="black-link"><a href="/venta/piso-guipuzcoa_gipuzkoa/asc/" onclick="(function(e){e.preventDefault();})(event)">Guipúzcoa - Gipuzkoa</a> (2.714)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000021"/><span class="black-link"><a href="/venta/piso-huelva/asc/" onclick="(function(e){e.preventDefault();})(event)">Huelva</a> (2.057)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000022"/><span class="black-link"><a href="/venta/piso-huesca/asc/" onclick="(function(e){e.preventDefault();})(event)">Huesca</a> (680)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000007"/><span class="black-link"><a href="/venta/piso-islas_baleares_illes_balears/asc/" onclick="(function(e){e.preventDefault();})(event)">Islas Baleares - Illes Balears</a> (4.948)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000023"/><span class="black-link"><a href="/venta/piso-jaen/asc/" onclick="(function(e){e.preventDefault();})(event)">Jaén</a> (1.330)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000026"/><span class="black-link"><a href="/venta/piso-la_rioja/asc/" onclick="(function(e){e.preventDefault();})(event)">La Rioja</a> (2.752)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000035"/><span class="black-link"><a href="/venta/piso-las_palmas/asc/" onclick="(function(e){e.preventDefault();})(event)">Las Palmas</a> (3.273)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000024"/><span class="black-link"><a href="/venta/piso-leon/asc/" onclick="(function(e){e.preventDefault();})(event)">León</a> (2.500)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000025"/><span class="black-link"><a href="/venta/piso-lleida/asc/" onclick="(function(e){e.preventDefault();})(event)">Lleida</a> (1.822)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000027"/><span class="black-link"><a href="/venta/piso-lugo/asc/" onclick="(function(e){e.preventDefault();})(event)">Lugo</a> (1.099)</span></label></li>
# <li class="selected"><label><input checked="checked" class="neverShow" data-prev-status="true" name="selectItem" type="checkbox" value="P00000000000028"/><span class="black-link"><a href="/venta/piso-madrid/asc/" onclick="(function(e){e.preventDefault();})(event)">Madrid</a> (15.753)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000029"/><span class="black-link"><a href="/venta/piso-malaga/asc/" onclick="(function(e){e.preventDefault();})(event)">Málaga</a> (16.511)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000052"/><span class="black-link"><a href="/venta/piso-melilla/asc/" onclick="(function(e){e.preventDefault();})(event)">Melilla</a> (296)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000030"/><span class="black-link"><a href="/venta/piso-murcia/asc/" onclick="(function(e){e.preventDefault();})(event)">Murcia</a> (9.206)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000031"/><span class="black-link"><a href="/venta/piso-navarra_nafarroa/asc/" onclick="(function(e){e.preventDefault();})(event)">Navarra - Nafarroa</a> (1.877)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000032"/><span class="black-link"><a href="/venta/piso-ourense/asc/" onclick="(function(e){e.preventDefault();})(event)">Ourense</a> (1.542)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000055"/><span class="black-link"><a href="/venta/piso-pais_vasco_frances_iparralde/asc/" onclick="(function(e){e.preventDefault();})(event)">País Vasco Francés - Iparralde</a> (59)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000034"/><span class="black-link"><a href="/venta/piso-palencia/asc/" onclick="(function(e){e.preventDefault();})(event)">Palencia</a> (1.099)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000036"/><span class="black-link"><a href="/venta/piso-pontevedra/asc/" onclick="(function(e){e.preventDefault();})(event)">Pontevedra</a> (3.948)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000037"/><span class="black-link"><a href="/venta/piso-salamanca/asc/" onclick="(function(e){e.preventDefault();})(event)">Salamanca</a> (2.713)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000038"/><span class="black-link"><a href="/venta/piso-santa_cruz_de_tenerife/asc/" onclick="(function(e){e.preventDefault();})(event)">Santa Cruz de Tenerife</a> (5.136)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000040"/><span class="black-link"><a href="/venta/piso-segovia/asc/" onclick="(function(e){e.preventDefault();})(event)">Segovia</a> (1.063)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000041"/><span class="black-link"><a href="/venta/piso-sevilla/asc/" onclick="(function(e){e.preventDefault();})(event)">Sevilla</a> (3.801)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000042"/><span class="black-link"><a href="/venta/piso-soria/asc/" onclick="(function(e){e.preventDefault();})(event)">Soria</a> (112)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000043"/><span class="black-link"><a href="/venta/piso-tarragona/asc/" onclick="(function(e){e.preventDefault();})(event)">Tarragona</a> (7.197)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000044"/><span class="black-link"><a href="/venta/piso-teruel/asc/" onclick="(function(e){e.preventDefault();})(event)">Teruel</a> (334)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000045"/><span class="black-link"><a href="/venta/piso-toledo/asc/" onclick="(function(e){e.preventDefault();})(event)">Toledo</a> (3.476)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000046"/><span class="black-link"><a href="/venta/piso-valencia/asc/" onclick="(function(e){e.preventDefault();})(event)">València</a> (19.506)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000047"/><span class="black-link"><a href="/venta/piso-valladolid/asc/" onclick="(function(e){e.preventDefault();})(event)">Valladolid</a> (3.322)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000048"/><span class="black-link"><a href="/venta/piso-vizcaya_bizkaia/asc/" onclick="(function(e){e.preventDefault();})(event)">Vizcaya - Bizkaia</a> (7.634)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000049"/><span class="black-link"><a href="/venta/piso-zamora/asc/" onclick="(function(e){e.preventDefault();})(event)">Zamora</a> (496)</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="P00000000000050"/><span class="black-link"><a href="/venta/piso-zaragoza/asc/" onclick="(function(e){e.preventDefault();})(event)">Zaragoza</a> (3.372)</span></label></li>
# </ul></div></div><input id="ddZonaProvincia" name="ddZonaProvincia" type="hidden" value=""/></div>
# </div>
# <div class="item">
# <div class="ms-parent w150" data-hidden-id="ddZonaComarca" id="dd_ddZonaComarca"><button class="ms-choice" type="button"><span class="black-link">Zonas</span></button><div class="ms-drop"><div class="joint"></div><div class="box"><ul><li class="selected"><label><input checked="checked" class="neverShow" data-prev-status="true" data-select-all-text="Zonas" name="selectAll" type="checkbox" value="P00000000000028"/><span class="black-link"><a href="/venta/piso-madrid/asc/" onclick="(function(e){e.preventDefault();})(event)">Todos</a></span></label></li>
# <li class=""><label class="optgroup"><input class="neverShow" name="selectItem" type="checkbox" value="C00000000000193"/><span class="black-link"><a href="/venta/piso-corredor_de_henares/asc/" onclick="(function(e){e.preventDefault();})(event)">Corredor de Henares</a> (1.451)</span></label></li>
# <li class=""><label class="optgroup"><input class="neverShow" name="selectItem" type="checkbox" value="C00000000000192"/><span class="black-link"><a href="/venta/piso-madrid_capital/asc/" onclick="(function(e){e.preventDefault();})(event)">Madrid Capital</a> (8.283)</span></label></li>
# <li class=""><label class="optgroup"><input class="neverShow" name="selectItem" type="checkbox" value="C00000000000194"/><span class="black-link"><a href="/venta/piso-madrid_noroeste/asc/" onclick="(function(e){e.preventDefault();})(event)">Madrid Noroeste</a> (1.587)</span></label></li>
# <li class=""><label class="optgroup"><input class="neverShow" name="selectItem" type="checkbox" value="C00000000000195"/><span class="black-link"><a href="/venta/piso-madrid_norte/asc/" onclick="(function(e){e.preventDefault();})(event)">Madrid Norte</a> (700)</span></label></li>
# <li class="child"><label><input class="neverShow" name="selectItem" type="checkbox" value="Z00000000000026"/><span class="black-link"><a href="/venta/piso-area_de_alcobendas/asc/" onclick="(function(e){e.preventDefault();})(event)">Área de Alcobendas</a> (528)</span></label></li>
# <li class="child"><label><input class="neverShow" name="selectItem" type="checkbox" value="Z00000000000027"/><span class="black-link"><a href="/venta/piso-area_de_buitrago_del_lozoya/asc/" onclick="(function(e){e.preventDefault();})(event)">Área de Buitrago del Lozoya</a> (15)</span></label></li>
# <li class="child"><label><input class="neverShow" name="selectItem" type="checkbox" value="Z00000000000028"/><span class="black-link"><a href="/venta/piso-area_de_guadalix_de_la_sierra/asc/" onclick="(function(e){e.preventDefault();})(event)">Área de Guadalix de la Sierra</a> (90)</span></label></li>
# <li class="child"><label><input class="neverShow" name="selectItem" type="checkbox" value="Z00000000000029"/><span class="black-link"><a href="/venta/piso-area_de_manzanares_el_real/asc/" onclick="(function(e){e.preventDefault();})(event)">Área de Manzanares El Real</a> (67)</span></label></li>
# <li class=""><label class="optgroup"><input class="neverShow" name="selectItem" type="checkbox" value="C00000000000196"/><span class="black-link"><a href="/venta/piso-madrid_sur/asc/" onclick="(function(e){e.preventDefault();})(event)">Madrid Sur</a> (2.205)</span></label></li>
# <li class=""><label class="optgroup"><input class="neverShow" name="selectItem" type="checkbox" value="C00000000000197"/><span class="black-link"><a href="/venta/piso-madrid_sureste/asc/" onclick="(function(e){e.preventDefault();})(event)">Madrid Sureste</a> (505)</span></label></li>
# <li class=""><label class="optgroup"><input class="neverShow" name="selectItem" type="checkbox" value="C00000000000198"/><span class="black-link"><a href="/venta/piso-madrid_suroeste/asc/" onclick="(function(e){e.preventDefault();})(event)">Madrid Suroeste</a> (1.022)</span></label></li>
# </ul></div></div><input id="ddZonaComarca" name="ddZonaComarca" type="hidden" value=""/></div>
# </div>
# </div>
# <div class="filtersDown filters clearfix">
# <div class="item">
# <div class="ms-parent w150" data-hidden-id="ddTipologias176" data-multiple="true" id="dd_ddTipologias176"><button class="ms-choice" type="button"><span class="black-link">Pisos y apartamentos (15.748) (0)</span></button><div class="ms-drop"><div class="joint"></div><div class="box multiple"><ul><li class=""><label><div class="fkCheckbox noEvents"><input class="neverShow" data-select-all-text="Tipo de inmueble" name="selectAll" type="checkbox" value="F002"/><label class="box" onclick=""><label class="icoTick" onclick=""></label></label></div><span class="black-link"><label>Todos</label></span></label></li>
# <li class=""><label><div class="fkCheckbox noEvents"><input class="neverShow" name="selectItem" type="checkbox" value="F002S022"/><label class="box" onclick=""><label class="icoTick" onclick=""></label></label></div><span class="black-link"><a href="/venta/casas-madrid/" onclick="(function(e){e.preventDefault();})(event)">Casas y chalets (7.758)</a></span></label></li>
# <li class=""><label><div class="fkCheckbox noEvents"><input checked="checked" class="neverShow" data-prev-status="true" name="selectItem" type="checkbox" value="F002S021"/><label class="box" onclick=""><label class="icoTick" onclick=""></label></label></div><span class="black-link"><a href="/venta/piso-madrid/" onclick="(function(e){e.preventDefault();})(event)">Pisos y apartamentos (15.748)</a></span></label></li>
# <li class=""><label><div class="fkCheckbox noEvents"><input class="neverShow" name="selectItem" type="checkbox" value="F002S024T015"/><label class="box" onclick=""><label class="icoTick" onclick=""></label></label></div><span class="black-link"><a href="/venta/aticos-madrid/" onclick="(function(e){e.preventDefault();})(event)">Áticos (662)</a></span></label></li>
# <li class=""><label><div class="fkCheckbox noEvents"><input class="neverShow" name="selectItem" type="checkbox" value="F002S024T010"/><label class="box" onclick=""><label class="icoTick" onclick=""></label></label></div><span class="black-link"><a href="/venta/duplexs-madrid/" onclick="(function(e){e.preventDefault();})(event)">Dúplex (980)</a></span></label></li>
# <li class=""><label><div class="fkCheckbox noEvents"><input class="neverShow" name="selectItem" type="checkbox" value="F002S024T039"/><label class="box" onclick=""><label class="icoTick" onclick=""></label></label></div><span class="black-link"><a href="/venta/estudios-madrid/" onclick="(function(e){e.preventDefault();})(event)">Estudios (113)</a></span></label></li>
# <li class=""><label><div class="fkCheckbox noEvents"><input class="neverShow" name="selectItem" type="checkbox" value="F002S023T022"/><label class="box" onclick=""><label class="icoTick" onclick=""></label></label></div><span class="black-link"><a href="/venta/fincas_rusticas-madrid/" onclick="(function(e){e.preventDefault();})(event)">Fincas rústicas (124)</a></span></label></li>
# <li class=""><label><div class="fkCheckbox noEvents"><input class="neverShow" name="selectItem" type="checkbox" value="F002S024T032"/><label class="box" onclick=""><label class="icoTick" onclick=""></label></label></div><span class="black-link"><a href="/venta/lofts-madrid/" onclick="(function(e){e.preventDefault();})(event)">Lofts (88)</a></span></label></li>
# </ul></div><div class="filtro"><input class="button button-secondary w100h27 ft13" type="button" value="Buscar"/></div></div><input id="ddTipologias176" name="ddTipologias" type="hidden" value=""/></div>
# </div>
# <div class="item">
# <div class="fkDropDown w150" id="dvFiltroPrecio">
# <div class="selector">
# <div class="tip">Precio</div>
# </div>
# <div class="list">
# <div class="joint"></div>
# <div class="box">
# <div class="subBoxPrecio clearfix">
# <div class="ms-parent w115 subSelect" data-hidden-id="ddPrecioMin176" id="dd_ddPrecioMin176"><button class="ms-choice" type="button"><span class="placeholder">Mínimo</span></button><div class="ms-drop"><div class="joint"></div><div class="box"><ul><li class="selected"><label><input checked="checked" class="neverShow" data-prev-status="true" data-select-all-text="Mínimo" name="selectAll" type="checkbox" value="0"/><span>Todos</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="10000"/><span>10.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="30000"/><span>30.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="60000"/><span>60.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="90000"/><span>90.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="120000"/><span>120.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="150000"/><span>150.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="180000"/><span>180.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="210000"/><span>210.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="240000"/><span>240.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="270000"/><span>270.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="300000"/><span>300.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="360000"/><span>360.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="420000"/><span>420.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="480000"/><span>480.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="600000"/><span>600.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="1000000"/><span>1.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="2000000"/><span>2.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="3000000"/><span>3.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="6000000"/><span>6.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="10000000"/><span>10.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="20000000"/><span>20.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="30000000"/><span>30.000.000 €</span></label></li>
# </ul></div></div><input id="ddPrecioMin176" name="ddPrecioMin" type="hidden" value=""/></div>
# <div class="ms-parent w115 subSelect" data-hidden-id="ddPrecioMax176" id="dd_ddPrecioMax176"><button class="ms-choice" type="button"><span class="placeholder">Máximo</span></button><div class="ms-drop"><div class="joint"></div><div class="box"><ul><li class="selected"><label><input checked="checked" class="neverShow" data-prev-status="true" data-select-all-text="Máximo" name="selectAll" type="checkbox" value="0"/><span>Todos</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="10000"/><span>10.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="30000"/><span>30.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="60000"/><span>60.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="90000"/><span>90.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="120000"/><span>120.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="150000"/><span>150.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="180000"/><span>180.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="210000"/><span>210.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="240000"/><span>240.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="270000"/><span>270.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="300000"/><span>300.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="360000"/><span>360.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="420000"/><span>420.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="480000"/><span>480.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="600000"/><span>600.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="1000000"/><span>1.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="2000000"/><span>2.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="3000000"/><span>3.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="6000000"/><span>6.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="10000000"/><span>10.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="20000000"/><span>20.000.000 €</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="30000000"/><span>30.000.000 €</span></label></li>
# </ul></div></div><input id="ddPrecioMax176" name="ddPrecioMax" type="hidden" value=""/></div>
# <button class="button w60h32" data-bind-id="filtroParrilla">Buscar</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="ms-parent w130" data-hidden-id="ddHabitaciones176" id="dd_ddHabitaciones176"><button class="ms-choice" type="button"><span class="placeholder">Habitaciones</span></button><div class="ms-drop"><div class="joint"></div><div class="box"><ul><li class="selected"><label><input checked="checked" class="neverShow" data-prev-status="true" data-select-all-text="Habitaciones" name="selectAll" type="checkbox" value="0"/><span>Todas</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="1"/><span>1 o más <span class="icoBed abs"></span></span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="2"/><span>2 o más <span class="icoBed abs"></span></span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="3"/><span>3 o más <span class="icoBed abs"></span></span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="4"/><span>4 o más <span class="icoBed abs"></span></span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="5"/><span>5 o más <span class="icoBed abs"></span></span></label></li>
# </ul></div></div><input id="ddHabitaciones176" name="ddHabitaciones" type="hidden" value=""/></div>
# </div>
# <div class="item">
# <div class="ms-parent w120" data-hidden-id="ddSuperficie176" id="dd_ddSuperficie176"><button class="ms-choice" type="button"><span class="placeholder">Superficie</span></button><div class="ms-drop"><div class="joint"></div><div class="box"><ul><li class="selected"><label><input checked="checked" class="neverShow" data-prev-status="true" data-select-all-text="Superficie" name="selectAll" type="checkbox" value="0"/><span>Todas</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="40"/><span>Desde 40 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="60"/><span>Desde 60 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="80"/><span>Desde 80 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="100"/><span>Desde 100 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="120"/><span>Desde 120 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="140"/><span>Desde 140 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="160"/><span>Desde 160 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="180"/><span>Desde 180 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="200"/><span>Desde 200 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="400"/><span>Desde 400 m²</span></label></li>
# <li class=""><label><input class="neverShow" name="selectItem" type="checkbox" value="600"/><span>Desde 600 m²</span></label></li>
# </ul></div></div><input id="ddSuperficie176" name="ddSuperficie" type="hidden" value=""/></div>
# </div>
# <div class="item">
# <div class="fkDropDown w110" id="dvMasFiltros">
# <div class="selector">
# <div class="tip"> Extras</div>
# </div>
# <div class="list left">
# <div class="joint"></div>
# <div class="box">
# <div class="subBoxMasFiltros casaPiso clearfix">
# <div class="columnFilter one-third">
# <div class="tipoFiltro">Características</div>
# <div class="fkCheckbox">
# <input id="chkCar_520" type="checkbox" value=""/>
# <label class="box" for="chkCar_520" onclick="">
# <label class="icoTick" for="chkCar_520" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkCar_520" onclick="">Garaje</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkCar_517" type="checkbox" value=""/>
# <label class="box" for="chkCar_517" onclick="">
# <label class="icoTick" for="chkCar_517" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkCar_517" onclick="">Ascensor</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkCar_516" type="checkbox" value=""/>
# <label class="box" for="chkCar_516" onclick="">
# <label class="icoTick" for="chkCar_516" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkCar_516" onclick="">Terraza</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkCar_522" type="checkbox" value=""/>
# <label class="box" for="chkCar_522" onclick="">
# <label class="icoTick" for="chkCar_522" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkCar_522" onclick="">Calefacción</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkCar_519" type="checkbox" value=""/>
# <label class="box" for="chkCar_519" onclick="">
# <label class="icoTick" for="chkCar_519" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkCar_519" onclick="">Piscina</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkCar_521" type="checkbox" value=""/>
# <label class="box" for="chkCar_521" onclick="">
# <label class="icoTick" for="chkCar_521" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkCar_521" onclick="">Trastero</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkCar_518" type="checkbox" value=""/>
# <label class="box" for="chkCar_518" onclick="">
# <label class="icoTick" for="chkCar_518" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkCar_518" onclick="">Jardín</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkCar_1526" type="checkbox" value=""/>
# <label class="box" for="chkCar_1526" onclick="">
# <label class="icoTick" for="chkCar_1526" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkCar_1526" onclick="">Aire acondicionado</label>
# </div>
# </div>
# </div>
# <div class="columnFilter one-third">
# <div class="tipoFiltro">Mostrar sólo</div>
# <div class="fkCheckbox">
# <input id="chkMS_11" type="checkbox" value=""/>
# <label class="box" for="chkMS_11" onclick="">
# <label class="icoTick" for="chkMS_11" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkMS_11" onclick="">Con fotos</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkMS_9" type="checkbox" value=""/>
# <label class="box" for="chkMS_9" onclick="">
# <label class="icoTick" for="chkMS_9" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkMS_9" onclick="">Con precio rebajado</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkMS_13" type="checkbox" value=""/>
# <label class="box" for="chkMS_13" onclick="">
# <label class="icoTick" for="chkMS_13" onclick=""></label>
# </label>
# <div class="label">
# <label for="chkMS_13" onclick="">Última semana</label>
# </div>
# </div>
# <div class="fkCheckbox">
# <input id="chkMS_14" type="checkbox" value=""/>
# ...
# <div class="bajada-precio-icon"></div>
# </div>
# </div>
# <div class="actions-item center">
# <div class="item favorito hide showExcept600" data-favorito="true" data-internal-fv="85857913219.104400" data-internal-fv-ispromotion="False" data-internal-fv-origen="Pisos" data-internal-fv-pos="0" data-internal-fv-zone="I28079040528006" title="Guarda este anuncio en una lista de favoritos. Necesitas tener una cuenta en pisos.com">
# <span class="favorito-hover">Guardar</span>
# <div class="favorito-icon"></div>
# </div>
# </div>
# <div class="actions-item right">
# <button class="button w120h30 item contactar" data-contact-bind="true" data-contact-ext="PaAnMod" data-contact-id="85857913219.104400" data-contact-is-prom="False" data-contact-origin="parrilla_segundaMano" data-contact-top="1000" type="submit">Contactar</button>
# </div>
# <div class="clear"></div>
# </div>
# <meta content="Piso en Lista" itemprop="name"/>
# <meta content="Piso en Lista" itemprop="description"/>
# <meta content="/comprar/piso-lista_barrio28006-85857913219_104400/" itemprop="url"/>
# <section itemprop="photo" itemscope="" itemtype="http://schema.org/ImageObject">
# <meta content="/comprar/piso-lista_barrio28006-85857913219_104400/" itemprop="url"/>
# <meta content="https://fotos4.imghs.net/nrd/1005/569/1005_57182521569_1_2019053023052343906.jpg" itemprop="contentUrl"/>
# </section>
# <section itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <meta itemprop="addressLocality"/>
# <meta itemprop="addressRegion"/>
# <meta itemprop="postalCode"/>
# <meta content="ES" itemprop="addressCountry"/>
# </section>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="pager">
# <div class="pager">
# <a class="button gray w162h32 left" data-click-analytics="clic-parrilla,paginador,anterior-bottom-v2-blankOnclic" href="/venta/piso-madrid/" id="lnkPagAnt" rel="prev">
# <span class="showOn980">Anterior</span> </a>
# <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-1-v2" href="/venta/piso-madrid/" rel="prev">1</a>
# <span class="item selected">2</span>
# <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-3-v2" href="/venta/piso-madrid/3/" rel="next">3</a>
# <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-4-v2" href="/venta/piso-madrid/4/">4</a>
# <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-5-v2" href="/venta/piso-madrid/5/">5</a>
# <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-6-v2" href="/venta/piso-madrid/6/">6</a>
# <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-7-v2" href="/venta/piso-madrid/7/">7</a>
# <span class="item ellipsis">...</span>
# <a class="item" data-click-analytics="clic-parrilla,paginador,pagina-525-v2" href="/venta/piso-madrid/525/">525</a>
# <a class="button gray w162h32 right" data-click-analytics="clic-parrilla,paginador,siguiente-bottom-v2-blankOnclic" href="/venta/piso-madrid/3/" id="lnkPagSig" rel="next">
# <span class="showOn980">Siguiente</span> </a>
# </div>
# <h2 class="subTitle">Venta de pisos y apartamentos en Madrid: 15.748 disponibles</h2>
# </div>
# <div id="contactarEspecialista"></div>
# <div class="btnUp button darkGray w50h50">
# <span class="icon icoUArrowThin" data-click-analytics="clic-parrilla,desplegable-H1,v2"></span>
# </div>
# </div>
# </div>
# <div class="content">
# <div class="adSenseDownPartial" data-querystring="0.1000.F002S021.P00000000000028.0.0X0.0.0.0X0.0.0X0X0.2.0.0X0.0X0.0" id="adSenseDownPartial">
# <div class="lazyLoad" data-ctrl="adSenseDownPartial">
# <div class="box">
# <span class="icon icoLoad"></span> Cargando...
#                         </div>
# </div>
# </div>
# <div class="neverShow" id="divGuardarBusquedaInferior">
# <div class="modals">
# <div class="integratedBlock">
# <form action="/Alerta/guardarAlertaIncrustado?cu=es" data-ajax="true" data-ajax-begin="$.Forms.desactivaBoton('.guardarAlerta input[type=&quot;submit&quot;]');" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-success="$.FormsAlerta.getAlertaResponse($.FormsAlerta.TIPO_FORM_INCRUSTADO);" data-ajax-update="#guardarAlerta" id="form0" method="post"> <div class="guardarAlerta clearfix" id="guardarAlerta">
# <div class="icono">
# <span class="icoBell"></span>
# </div>
# <h3 class="aviso">
#                                 Te avisamos de las últimas novedades en pisos y apartamentos en Madrid
#                             </h3>
# <div class="alerta clearfix">
# <input class="button blue w140h32" type="submit" value="Guardar búsqueda"/>
# <div class="fkInput w250">
# <input data-default-value="Escribe tu e-mail" data-val="true" data-val-regex="Introduce un e-mail correcto." data-val-regex-pattern="^[\w!#$%&amp;'*+\-/=?\^_`{|}~]+(\.[\w!#$%&amp;'*+\-/=?\^_`{|}~]+)*(?!.*@.*@)@[^-.]((([\-\w]+\.)+[a-zA-Z]{2,})|(([0-9]{1,3}\.){3}[0-9]{1,3}))$" data-val-required="Introduce un e-mail correcto." id="email" name="email" placeholder="" type="text" value=""/>
# </div>
# <span class="field-validation-valid" data-valmsg-for="email" data-valmsg-replace="true"></span>
# </div>
# <div class="contact-line check">
# <div class="error"><span class="field-validation-valid inputfield-error" data-valmsg-for="AvisoLegal" data-valmsg-replace="true"></span></div>
# <div class="chkBox">
# <div class="fkCheckbox">
# <input data-val="true" data-val-required="The AvisoLegal field is required." id="AvisoLegalAA3" name="AvisoLegal" type="checkbox" value="true"/><input name="AvisoLegal" type="hidden" value="false"/>
# <label class="box" for="AvisoLegalAA3" onclick="">
# <label class="icoTick" for="AvisoLegalAA3" onclick=""></label>
# </label>
# </div>
# </div>
# <label class="checkbox-text" for="AvisoLegalAA3">
#                                     He leído el <a href="//www.pisos.com/avisolegal" target="_blank">aviso legal y la política de privacidad</a>
# </label>
# </div>
# <input id="AnuncioId" name="AnuncioId" type="hidden" value=""/>
# <input data-val="true" data-val-required="The IsPromotion field is required." id="IsPromotion" name="IsPromotion" type="hidden" value="False"/>
# <input data-val="true" data-val-required="The OrigenPortalAnuncio field is required." id="OrigenPortalAnuncio" name="OrigenPortalAnuncio" type="hidden" value="Pisos"/>
# <input id="hdnQueryString" name="queryString" type="hidden" value="0.1000.F002S021.P00000000000028.0.0X0.0.0.0X0.0.0X0X0.2.0.0X0.0X0.0"/>
# <input data-val="true" data-val-required="The Origen field is required." id="hdnOrigenAlerta" name="Origen" type="hidden" value="AlertaParrilla_BarraInferior"/>
# <input id="hdnTipoAlerta" name="hdnTipoAlerta" type="hidden" value="0"/>
# </div>
# </form> </div>
# </div>
# </div>
# </div>
# <div class="content">
# <div class="linksSeo clearfix">
# <h3 class="titulo">Te recomendamos...</h3>
# <div class="tipo">
# <span class="subtitulo">Top municipios</span>
# <div class="columna">
# <a class="item" href="/venta/piso-madrid_capital_zona_urbana/" title="Casas y pisos en venta en Madrid Capital">Madrid Capital</a>
# <a class="item" href="/venta/piso-torrejon_de_ardoz/" title="Casas y pisos en venta en Torrejón de Ardoz">Torrejón de Ardoz</a>
# <a class="item" href="/venta/piso-mostoles/" title="Casas y pisos en venta en Móstoles">Móstoles</a>
# <a class="item" href="/venta/piso-alcala_de_henares/" title="Casas y pisos en venta en Alcalá de Henares">Alcalá de Henares</a>
# <a class="item" href="/venta/piso-fuenlabrada/" title="Casas y pisos en venta en Fuenlabrada">Fuenlabrada</a>
# </div>
# </div>
# <div class="cerca">
# <span class="subtitulo">Cerca de Madrid</span>
# <div class="columna col0">
# <a class="item" href="/venta/piso-madrid_capital_zona_urbana/" title="Venta De Pisos y apartamentos en Madrid Capital">Madrid Capital</a>
# <a class="item" href="/venta/piso-alcobendas/" title="Venta De Pisos y apartamentos en Alcobendas">Alcobendas</a>
# <a class="item" href="/venta/piso-pozuelo_de_alarcon/" title="Venta De Pisos y apartamentos en Pozuelo de Alarcón">Pozuelo de Alarcón</a>
# <a class="item" href="/venta/piso-tres_cantos/" title="Venta De Pisos y apartamentos en Tres Cantos">Tres Cantos</a>
# <a class="item" href="/venta/piso-san_sebastian_de_los_reyes/" title="Venta De Pisos y apartamentos en San Sebastián de los Reyes">San Sebastián de los Reyes</a>
# </div><div class="columna col1"> <a class="item" href="/venta/piso-las_rozas_de_madrid/" title="Venta De Pisos y apartamentos en Las Rozas de Madrid">Las Rozas de Madrid</a>
# <a class="item" href="/venta/piso-majadahonda/" title="Venta De Pisos y apartamentos en Majadahonda">Majadahonda</a>
# <a class="item" href="/venta/piso-coslada/" title="Venta De Pisos y apartamentos en Coslada">Coslada</a>
# <a class="item" href="/venta/piso-paracuellos_de_jarama/" title="Venta De Pisos y apartamentos en Paracuellos de Jarama">Paracuellos de Jarama</a>
# <a class="item" href="/venta/piso-boadilla_del_monte/" title="Venta De Pisos y apartamentos en Boadilla del Monte">Boadilla del Monte</a>
# </div><div class="columna col2"> <a class="item" href="/venta/piso-alcorcon/" title="Venta De Pisos y apartamentos en Alcorcón">Alcorcón</a>
# <a class="item" href="/venta/piso-leganes/" title="Venta De Pisos y apartamentos en Leganés">Leganés</a>
# <a class="item" href="/venta/piso-colmenar_viejo/" title="Venta De Pisos y apartamentos en Colmenar Viejo">Colmenar Viejo</a>
# <a class="item" href="/venta/piso-cobena/" title="Venta De Pisos y apartamentos en Cobeña">Cobeña</a>
# <a class="item" href="/venta/piso-torrelodones/" title="Venta De Pisos y apartamentos en Torrelodones">Torrelodones</a>
# </div><div class="columna col3"> </div>
# </div>
# </div>
# </div>
# <input id="hdnTipoDisp" name="hdnTipoDisp" type="hidden" value="Mobile"/>
# <script type="text/javascript">
#     if ("headScripts" in jQuery) { $.headScripts.parrillaOnError(); }
# </script>
# </div>
# <link href="https://statics.imghs.net/bundles/css/desktop-footer-min-cef6c40f.css" rel="stylesheet"/>
# <footer>
# <div class="footer">
# <div class="footer-content">
# <div class="footer-breadcrumb" itemprop="breadcrumb">
# <div class="item">
# <a href="/" target="_self">Inicio</a>
# </div>
# <div class="separator">&gt;</div>
# <div class="item">
#  Pisos y apartamentos en venta en Madrid            </div>
# <div class="clear"></div>
# </div>
# <div class="footer-row">
# <div class="footer-sociallinks">
# <img alt="pisos.com" class="footer-logo" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/logo-pisos-footer.svg" src="/Images/assets/blank1x1.png" width="75"/>
# <a href="https://twitter.com/pisoscom" rel="nofollow" target="_blank">
# <img alt="Twitter" class="icon-social" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/footer-twitter.svg" src="/Images/assets/blank1x1.png"/>
# </a>
# <a href="https://www.facebook.com/pisoscom" rel="nofollow" target="_blank">
# <img alt="Facebook" class="icon-social" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/footer-facebook.svg" src="/Images/assets/blank1x1.png"/>
# </a>
# </div>
# <div class="footer-stores">
# <a class="mobile-landing" href="https://www.pisos.com/movil/" rel="nofollow" target="_blank">
# <span>También en tu móvil</span>
# <img alt="icono-moviles" src="https://statics.imghs.net/Images/icono-moviles.svg"/>
# </a>
# <a data-click-analytics="clic-descarga,app,footer" href="https://play.google.com/store/apps/details?id=com.vocento.pisos" rel="nofollow" target="_blank">
# <img alt="icono-footer-android" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/icono-footer-android.svg" src="/Images/assets/blank1x1.png"/>
# <span>Para Android </span>
# </a>
# <a data-click-analytics="clic-descarga,app,footer" href="https://itunes.apple.com/us/app/pisos.com/id572483925?mt=8" rel="nofollow" target="_blank">
# <img alt="icono-footer-ios" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/icono-footer-ios.svg" src="/Images/assets/blank1x1.png"/>
# <span>Para IOS</span>
# </a>
# </div>
# </div>
# <div class="footer-links">
# <div class="footer-column">
# <div class="title">Corporativo</div>
# <div class="item">
# <a href="https://www.pisos.com/sobrepisos/" rel="nofollow" target="">Sobre pisos.com</a>
# </div>
# <div class="item">
# <a href="https://www.pisos.com/sobrepisos/contactanos/" rel="nofollow" target="">Contactar</a>
# </div>
# </div>
# <div class="footer-column">
# <div class="title"> </div>
# <div class="item">
# <a href="https://www.pisos.com/saladeprensa/" rel="nofollow" target="">Sala de prensa</a>
# </div>
# <div class="item">
# <a href="https://www.pisos.com/mapaweb/">Mapa web</a>
# </div>
# </div>
# <div class="footer-column">
# <div class="title">Secciones</div>
# <div class="item">
# <a href="https://gestion.pisos.com/pta/pta_paso1.aspx" rel="nofollow">Publica tu anuncio</a>
# </div>
# <div class="item">
# <a href="https://www.pisos.com/hipotecas/">Hipotecas</a>
# </div>
# </div>
# <div class="footer-column">
# <div class="title"> </div>
# <div class="item">
# <a href="https://www.pisos.com/servicios/" rel="nofollow" target="">Servicios</a>
# </div>
# <div class="item">
# <a href="//www.pisos.com/aldia/">Pisos al día</a>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# <div class="footer-copyright">
# <div class="copyright">Copyright © 1998-2019 Portal inmobiliario pisos.com es un producto de <a href="http://www.habitatsoft.com/" target="_blank">HabitatSoft</a> | <a data-bind-id="avisoLegal">Aviso legal y política de privacidad</a></div>
# <div class="vocento">
# <a href="https://www.vocento.com/" target="_blank">
# <img alt="Vocento" data-lazy="true" data-lazy-img="https://statics.imghs.net/Images/logo-vocento.svg" src="/Images/assets/blank1x1.png"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <span data-bot="false" data-ip="81.0.23.142" data-new-session="false" data-page-name="resultados-navegacion/viviendas-venta/madrid/provincia/madrid/2" data-session-id="" data-url="http://www.pisos.com/venta/piso-madrid/2/" data-url-ref="" data-var-ads="Venta/parrillas#prv=28#ti=F002S021#tu=2#mob=0" id="gaVars"></span>
# <span data-var="1,tipo_operacion,venta,3;2,tipo_inmueble,piso,3;3,pr_madrid,,3;5,usuario,no-loggado,2" id="gaCusVar"></span>
# <span data-base-gestion-url="https://gestion.pisos.com/" data-base-url="https://www.pisos.com/" id="AdditionalVars"></span>
# <span data-category="Venta" data-category-id="" data-exclude-rtbhouse="false" data-id="" data-id-list="94198207921.997755,9006950068.109700,93420502200.101800,94183796118.109300,88396535652.104400,945856909523055.109700,93389918534.995758,94181579146.101800,94175007538.149200,93338616709.109300,93426476345.100500,92576193051.100500,93394502626.995758,90056004224.100500,93334078717.109300,94197480219.100500,92526632830.997869,94231056919.100500,92534256010.998331,89232638534.510261,90853895315.992271,92513508417.109300,94240631085.515111,92573887005.100500,92540793095.993744,9113098299.109700,83395212035.390800,92519655450.108900,94174864462.100500,85857913219.104400" data-type="listing" data-var-hash="mHKAyYGLw7B5JdS8yAaa" id="RTBHouse"></span>
# <input id="hdnsrv" type="hidden" value="SHADOW"/>
# <script data-cmp="true" src="//static.vocento.com/voonto2/latest/voonto.js"></script>
# <script data-legacy-comscore-mmx="7715761" data-property-id="9cb981201c2474d6a4604b74a0c58d334d976adc" src="//static.vocento.com/tag-manager/latest/vtm.js"></script>
# <script>
#     if (typeof (TagManager) !== "undefined") {
#         TagManager.ready.then(function () { TagManager.set({ sitioRegistro: 'pisos' }).track(); });
#     }
# </script>
# <noscript>
# <img border="0" height="1" src="//vocento.d3.omtrdc.net/b/ss/vocpisos,voces/1/G.4--S/886540940?pageName=&amp;g=" width="1"/>
# </noscript>
# <link href="https://statics.imghs.net/bundles/css/common-mediaqueries-min-1a7ef7f1.css" rel="stylesheet"/> <script src="https://statics.imghs.net/bundles/js/common-jquery-min-aa814b7a.js"></script>
# <script src="https://statics.imghs.net/bundles/js/common-google-min-f980b9fb.js"></script>
# <script src="https://statics.imghs.net/bundles/js/common-shared-min-7caaf192.js"></script>
# <script src="https://statics.imghs.net/bundles/js/common-business-min-bc58aff4.js"></script>
# <script src="https://statics.imghs.net/bundles/js/desktop-grid-min-5e9ae7d0.js"></script>
# <script type="text/javascript">
#         var _emailSubscrito = '';
#         var _idUsuario = 0;
#     </script>
# </body>
# </html>

# %%
anuncios = primera_pagina.find_all('div', 'information exclusivo')

# %%
pisos = []
for piso in anuncios:
    items = {}
    chars = piso.find('div', 'characteristics')
    print(chars)
# Out:
# [<div class="information exclusivo">
#  <img class="anunciante-logo" src="https://fotos.imghs.net/prof/logos/logo_511263_24020201410518.jpg"/>
#  <div class="priceBox">
#  <div class="price">
#                          187.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-naranjo_la_serna-94198207921_997755/">Piso en Zona La Serna</a>
#  </h3>
#  <div class="location">
#                  Naranjo-La Serna (Fuenlabrada)
#              </div>
#  <div class="description">
#                  Piso de 114 m² exterior y muy luminoso en zona avenida españa. Compuesto de 3 dormitorios, salón, cocina, 2 baño...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              114 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              1ª planta
#                          </div>
#  <div class="item">
#                              1.640
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" src="https://fotos.imghs.net/prof/logos/Logo_994052_72386.jpg"/>
#  <div class="priceBox">
#  <div class="price">
#                          176.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-valdemoro_estacion-9006950068_109700/">Piso en calle Alfonso VI,  S/N</a>
#  </h3>
#  <div class="location">
#                  Estación (Valdemoro)
#              </div>
#  <div class="description">
#                  Vivienda 40. Piso en una finca de obra nueva de 80 m2 de superficie construida y emplazado en la zona de Valdemo...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              80 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              2
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              2.189
#   €/m²                        </div>
#  <div class="item extra">
#                              Obra nueva
#                          </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <a href="/inmobiliaria-estudio_atocha_estacion_993483_0/" onclick="event.stopPropagation();">
#  <img class="anunciante-logo" src="https://fotos.imghs.net/prof/logos/logo_259897_140702017145758.jpg"/>
#  </a>
#  <div class="priceBox">
#  <div class="price">
#                          400.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-chopera28045-93420502200_101800/">Piso en calle Fernando Poo</a>
#  </h3>
#  <div class="location">
#                  Chopera (Distrito Arganzuela. Madrid Capital)
#              </div>
#  <div class="description">
#                  Sexta planta exterior con ascensor, portero físico, plaza de garaje, terraza de 42 m2, 4 dormitorios, salón inde...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              120 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              4
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              3
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              3.333
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_992510.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          145.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-puente_de_vallecas_portazgo28018-94183796118_109300/">Piso en Vallecas</a>
#  </h3>
#  <div class="location">
#                  Portazgo (Distrito Puente de Vallecas. Madrid Capital)
#              </div>
#  <div class="description">
#                  Ref. 12644 piso muy amplio de 88 metros cuadrados construidos distribuido en dos dormitorios, baño con mampara, ...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              88 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              2
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              1.647
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/Logo_998376_20190321124046.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          655.000 €
#                      </div>
#  <div class="price-old">Ha bajado 85.000 €</div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-fuente_del_berro28028-88396535652_104400/">Piso en calle Bocangel</a>
#  </h3>
#  <div class="location">
#                  Fuente del Berro (Distrito Salamanca. Madrid Capital)
#              </div>
#  <div class="description">
#                  Magnífica casa EN URBANIZACIÓN CON PISCINA y zonas verdes, en muy buen estado en Fuente del Berro, con zonas de ...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              150 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              4
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              2ª planta
#                          </div>
#  <div class="item">
#                              4.366
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <a href="/inmobiliaria-inmobiliaria_medem/" onclick="event.stopPropagation();">
#  <img class="anunciante-logo" data-lazy="true" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/Logo_515749_38226_24644.jpg" src="..."/>
#  </a>
#  <div class="priceBox">
#  <div class="price">
#                          975.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-chamartin_hispanoamerica28016-945856909523055_109700/">Piso en Chamartin</a>
#  </h3>
#  <div class="location">
#                  Hispanoamérica (Distrito Chamartín. Madrid Capital)
#              </div>
#  <div class="description">
#                  Zona residencial C/ Serrano.
#  Fantástico piso exterior de 195 metros construidos.
#  Todas las orientaciones.
#  Salón ...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              195 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              5
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              3
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              5ª planta
#                          </div>
#  <div class="item">
#                              5.000
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_995758.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          148.000 €
#                      </div>
#  <div class="price-old">Ha bajado 3.000 €</div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-villaverde_san_andres28021-93389918534_995758/">Piso en calle Gomez Acebo</a>
#  </h3>
#  <div class="location">
#                  San Andrés (Distrito Villaverde. Madrid Capital)
#              </div>
#  <div class="description">
#                  Excelente piso reformado en venta, de dos dormitorios, con salón amplio, cuarto de baño con plato de ducha y mam...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              69 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              2
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              Bajo
#                          </div>
#  <div class="item">
#                              2.144
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <a href="/inmobiliaria-estudio_atocha_estacion_993483_0/" onclick="event.stopPropagation();">
#  <img class="anunciante-logo" data-lazy="true" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_259897_140702017145758.jpg" src="..."/>
#  </a>
#  <div class="priceBox">
#  <div class="price">
#                          375.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-acacias28005-94181579146_101800/">Piso en calle Peñuelas</a>
#  </h3>
#  <div class="location">
#                  Acacias (Distrito Arganzuela. Madrid Capital)
#              </div>
#  <div class="description">
#                  Quinta planta exterior con ascensor, plaza de garaje OPCIONAL, terraza y vistas a Calle Peñuelas!
#
#  Inmueble en q...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              112 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              4
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              3.348
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/Logo_1492_20180403104026.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          1.600.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-chamartin_hispanoamerica28016-94175007538_149200/">Piso en Chamartin</a>
#  </h3>
#  <div class="location">
#                  Hispanoamérica (Distrito Chamartín. Madrid Capital)
#              </div>
#  <div class="description">
#                  Unica Inmobiliaria (Chamartin, telf. 913577065), ofrece esta estupenda vivienda con una situación excepcional di...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              283 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              5
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              3
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              5ª planta
#                          </div>
#  <div class="item">
#                              5.653
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_992510.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          309.700 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-palomeras_sureste28031-93338616709_109300/">Piso en Cocherón</a>
#  </h3>
#  <div class="location">
#                  Palomeras Sureste (Distrito Puente de Vallecas. Madrid Capital)
#              </div>
#  <div class="description">
#                  Ref 12037; zona cocheron de la villa. Precioso piso totalmente reformado con excelentes calidades , originalment...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              106 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              2.921
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/Logo_998376_20190321124046.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          320.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-ibiza28009-93426476345_100500/">Piso en calle Ibiza</a>
#  </h3>
#  <div class="location">
#                  Ibiza (Distrito Retiro. Madrid Capital)
#              </div>
#  <div class="description">
#                  Bonito apartamento reformado DE 40 M2 en buen estado.Se encuentra ubicado en uno de los bulevares mas bonitos de...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              40 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              1
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              4ª planta
#                          </div>
#  <div class="item">
#                              8.000
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <a href="/inmobiliaria-torresrubi_gestion_inmobiliaria_997817_0/" onclick="event.stopPropagation();">
#  <img class="anunciante-logo" data-lazy="true" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_514728_0405020172070.jpg" src="..."/>
#  </a>
#  <div class="priceBox">
#  <div class="price">
#                          130.000 €
#                      </div>
#  <div class="price-old">Ha bajado 10.000 €</div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-palomeras_sureste28038-92576193051_100500/">Piso en calle San Claudio</a>
#  </h3>
#  <div class="location">
#                  Palomeras Sureste (Distrito Puente de Vallecas. Madrid Capital)
#              </div>
#  <div class="description">
#                  Oportunidad de adquirir un piso  3 habitaciones (1 de ellas doble y  2 individuales),  1 baño completo con plato...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              65 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              2ª planta
#                          </div>
#  <div class="item">
#                              2.000
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_995758.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          105.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-villaverde_san_andres28021-93394502626_995758/">Piso en calle Juan Peñalver</a>
#  </h3>
#  <div class="location">
#                  San Andrés (Distrito Villaverde. Madrid Capital)
#              </div>
#  <div class="description">
#                  Vivienda totalmente reformada en venta, de 2 dormitorios amplios, salón, cuarto de baño y cocina, con calefacció...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              65 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              2
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              Bajo
#                          </div>
#  <div class="item">
#                              1.615
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/Logo_998376_20190321124046.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          590.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-fuente_del_berro28028-90056004224_100500/">Piso en calle Fundadores</a>
#  </h3>
#  <div class="location">
#                  Fuente del Berro (Distrito Salamanca. Madrid Capital)
#              </div>
#  <div class="description">
#                  "EXCELENTE PISO EN FUENTE DEL BERRO.
#
#   Piso ubicado en uno de los exclusivos barrios residenciales de Madrid, a...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              145 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              4
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              3ª planta
#                          </div>
#  <div class="item">
#                              4.068
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_992510.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          121.100 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-puente_de_vallecas_portazgo28038-93334078717_109300/">Piso en Vallecas</a>
#  </h3>
#  <div class="location">
#                  Portazgo (Distrito Puente de Vallecas. Madrid Capital)
#              </div>
#  <div class="description">
#                  REF: 5664 Piso en  Alto Arenal en edificio con ascensor. Distribuido en dos dormitorios, cocina amuebl...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              61 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              2
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              1.985
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <a href="/inmobiliaria-look_and_find_moratalaz/" onclick="event.stopPropagation();">
#  <img class="anunciante-logo" data-lazy="true" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_981721_07020201811433.jpg" src="..."/>
#  </a>
#  <div class="priceBox">
#  <div class="price">
#                          235.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-marroquina28030-94197480219_100500/">Piso en Marroquina</a>
#  </h3>
#  <div class="location">
#                  Marroquina (Distrito Moratalaz. Madrid Capital)
#              </div>
#  <div class="description">
#                  Vivienda con ascensor para reformar de 3 habitaciones, con excelente ubicación. Amplio salón, cocina con office ...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              96 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              4
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              2ª planta
#                          </div>
#  <div class="item">
#                              2.447
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_517207_10030201417460.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          92.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-puente_de_vallecas_entrevias28053-92526632830_997869/">Piso en calle Ronda del Sur</a>
#  </h3>
#  <div class="location">
#                  Entrevías (Distrito Puente de Vallecas. Madrid Capital)
#              </div>
#  <div class="description">
#                  "imagina hogar vende en exclusiva, fantástico piso muy luminoso en entrevías de 75 m². Se distribuye en hall rec...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              77 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              1ª planta
#                          </div>
#  <div class="item">
#                              1.194
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <a href="/inmobiliaria-blanco_o_negro_servicios_inmobiliarios_cadorsur_20/" onclick="event.stopPropagation();">
#  <img class="anunciante-logo" data-lazy="true" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_517902_14040201413382.jpg" src="..."/>
#  </a>
#  <div class="priceBox">
#  <div class="price">
#                          169.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-pau_de_carabanchel28054-94231056919_100500/">Piso en Avenida de La Peseta</a>
#  </h3>
#  <div class="location">
#                  Pau de Carabanchel (Distrito Carabanchel. Madrid Capital)
#              </div>
#  <div class="description">
#                  Oportunidad!!! Apartamento en el Pau de Carabanchel para pareja o inversión de 60 m2 construidos de los cuales 5...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              60 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              1
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              2ª planta
#                          </div>
#  <div class="item">
#                              2.816
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_539659_100602014111940.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          175.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-getafe_juan_de_la_cierva-92534256010_998331/">Piso en calle Camino Viejo de Pinto</a>
#  </h3>
#  <div class="location">
#                  Juan de la Cierva (Getafe)
#              </div>
#  <div class="description">
#                  Vivienda situada en calle Camino Viejo de Pinto 5º planta con ascensor -salón independiente-3 dormitorios -2 w.c...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              90 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              5ª planta
#                          </div>
#  <div class="item">
#                              1.944
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_616175_260702016183812.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          149.000 €
#                      </div>
#  <div class="price-old">Ha bajado 4.000 €</div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-galapagar_centro-89232638534_510261/">Piso en calle Palomeras</a>
#  </h3>
#  <div class="location">
#                  Centro (Galapagar)
#              </div>
#  <div class="description">
#                  Exclusivas Santo Mauro les ofrece piso de 3 habitaciones en Centro Urbano de Galapagar. Baño y aseo. Paredes con...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              91 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              2ª planta
#                          </div>
#  <div class="item">
#                              1.637
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_204232_281002013113214.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          175.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-villalba_pueblo-90853895315_992271/">Piso en calle Fuente del Álamo</a>
#  </h3>
#  <div class="location">
#                  Villalba Pueblo (Collado Villalba)
#              </div>
#  <div class="description">
#                  PISO de reciente construcción. Con 75m² construidos, 3 dormitorios, 1 baño completo. Salón comedor muy luminoso,...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              75 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              1ª planta
#                          </div>
#  <div class="item">
#                              2.333
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_992510.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          108.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-palomeras_sureste28018-92513508417_109300/">Piso en Vallecas</a>
#  </h3>
#  <div class="location">
#                  Palomeras Sureste (Distrito Puente de Vallecas. Madrid Capital)
#              </div>
#  <div class="description">
#                  REF: 12317 Piso de dos habitaciones amplias en segunda planta con ascensor recientemente instalado. Un cuar...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              50 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              2
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              2.160
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_913193_040902017105820.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          129.900 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-cerro_el_molino-94240631085_515111/">Piso en calle Alemania</a>
#  </h3>
#  <div class="location">
#                  Cerro-El Molino (Fuenlabrada)
#              </div>
#  <div class="description">
#                  Redpiso vende piso en Parque Granada de 90m2 construidos. Se distribuye en amplio salón de paso con terraza acri...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              90 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              3ª planta
#                          </div>
#  <div class="item">
#                              1.443
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_378822_17100201313545.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          139.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-san_diego28053-92573887005_100500/">Piso en calle de Palomeras</a>
#  </h3>
#  <div class="location">
#                  San Diego (Distrito Puente de Vallecas. Madrid Capital)
#              </div>
#  <div class="description">
#                  "cm casa madrid vende en exclusiva
#  Fantástico piso en finca semi-nueva de:
#  2 dormitorios con 2 baños(uno de e...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              91 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              2
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              1ª planta
#                          </div>
#  <div class="item">
#                              1.527
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_993744.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          129.000 €
#                      </div>
#  <div class="price-old">Ha bajado 3.000 €</div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-alcorcon_casco_antiguo-92540793095_993744/">Piso en Casco Antiguo</a>
#  </h3>
#  <div class="location">
#                  Casco Antiguo (Alcorcón)
#              </div>
#  <div class="description">
#                  Inmobiliaria maqueda vende amplio piso de 85 m² muy próximo a renfe y metro (alcorcón central). Salón independie...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              85 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              3ª planta
#                          </div>
#  <div class="item">
#                              1.517
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/Logo_994052_72386.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          178.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-valdemoro_estacion-9113098299_109700/">Piso en calle Alfonso VI,  S/N</a>
#  </h3>
#  <div class="location">
#                  Estación (Valdemoro)
#              </div>
#  <div class="description">
#                  Vivienda 50. Piso en una finca de obra nueva de 80 m2 de superficie construida y emplazado en la zona de Valdemo...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              80 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              2
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              2.213
#   €/m²                        </div>
#  <div class="item extra">
#                              Obra nueva
#                          </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/Logo_3908.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          140.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-centro_embajadores_lavapies28012-83395212035_390800/">Piso en calle Mesón de Paredes</a>
#  </h3>
#  <div class="location">
#                  Embajadores-Lavapiés (Distrito Centro. Madrid Capital)
#              </div>
#  <div class="description">
#                  Vivienda en barrio de Lavapies. Ideal como inversión y posteriormente alquilar.
#  Tiene 32, 75 metros cuadrados, ...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              35 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              2
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              Bajo
#                          </div>
#  <div class="item">
#                              4.000
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_627021_130802015132930.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          129.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-ciudad_lineal_pueblo_nuevo28017-92519655450_108900/">Piso en calle Mazo, nº 6</a>
#  </h3>
#  <div class="location">
#                  Pueblo Nuevo (Distrito Ciudad Lineal. Madrid Capital)
#              </div>
#  <div class="description">
#                  Características del edificio:
#
#  - Construido en 1965, fachada enfoscada, edificio rehabilitado con la inspección ...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              70 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              1
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              1.842
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/logo_452275_160402018171311.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          134.800 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-el_mirador_el_grillero-94174864462_100500/">Piso en El Mirador-El Grillero</a>
#  </h3>
#  <div class="location">
#                  El Mirador-El Grillero (Arganda del Rey)
#              </div>
#  <div class="description">
#                  ¿ Te gustaría adquirir tu 1ª vivienda? ¿Todos tus hijos se han independizado y la casa ya es demasiado grande? ¡...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              81 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              3
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              1.664
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>, <div class="information exclusivo">
#  <img class="anunciante-logo" data-lazy-error-action="selfRm" data-lazy-img="https://fotos.imghs.net/prof/logos/Logo_998376_20190321124046.jpg" src="..."/>
#  <div class="priceBox">
#  <div class="price">
#                          860.000 €
#                      </div>
#  <div class="clearfix"></div>
#  </div>
#  <div class="ad">
#  <span class="txtlnkpar"></span>
#  </div>
#  <h3 class="title">
#  <a class="anuncioLink" data-cancel-events="" data-suggested="" href="/comprar/piso-lista_barrio28006-85857913219_104400/">Piso en Lista</a>
#  </h3>
#  <div class="location">
#                  Lista (Distrito Salamanca. Madrid Capital)
#              </div>
#  <div class="description">
#
#   avaris, le presenta este maravilloso piso en la calle General Díaz Porlier. Se trata de un piso exterior de 18...
#              </div>
#  <div class="characteristics">
#  <div class="item">
#                              179 m²
#                          </div>
#  <div class="item" data-rooms="true">
#                              4
#                                  <span class="icon icoBed"></span>
#  </div>
#  <div class="item">
#                              2
#                                  <span class="icon icoBath"></span>
#  </div>
#  <div class="item">
#                              1ª planta
#                          </div>
#  <div class="item">
#                              4.804
#   €/m²                        </div>
#  <div class="clear"></div>
#  </div>
#  </div>]
